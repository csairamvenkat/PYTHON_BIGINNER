# %%
# Using Input Function to Create a Prompt
def create_prompt():
 topic=input("Enter topic for story")
 tone=input("Entrr tone for story eg : Serious,comedy etc")
 
 prompt=f"Write a {tone} story about {topic}."
 return prompt


user_prompt=create_prompt()
print("Your prompt is:",user_prompt)
# Out:
# Your prompt is: Write a Serious story about Kubera.

# %%
# Using Lits
topics=["AI","ISRO","Indian Histrory"]
tones=["Serious","Comedy","Suspense"]

prompts=[]
for topic in topics:
    for tone in tones:
        prompt=f"Write a {tone} story about {topic}."
        prompts.append(prompt)
        
print("Generated prompts:")
for p in prompts:
    print(p)
# Out:
# Generated prompts:
# Write a Serious story about AI.
# Write a Comedy story about AI.
# Write a Suspense story about AI.
# Write a Serious story about ISRO.
# Write a Comedy story about ISRO.
# Write a Suspense story about ISRO.
# Write a Serious story about Indian Histrory.
# Write a Comedy story about Indian Histrory.
# Write a Suspense story about Indian Histrory.

# %%
#Using Templates
def create_summary_prompt(text):
    prompt_template="Summerize the following Text :{text}"
    return prompt_template.format(text=text)

input_text=input("Enter text to summarize:")
summary_prompt=create_summary_prompt(input_text)
print("Your summary prompt is:", summary_prompt)
# Out:
# Your summary prompt is: Summerize the following Text :Artificial intelligence (AI) refers to the simulation of human intelligence in machines, enabling them to perform tasks that typically require human intellect, such as learning, problem-solving, and decision-making. AI systems use algorithms and data to learn, adapt, and improve over time, making them capable of performing complex tasks with increasing accuracy. AI is rapidly transforming various industries, from healthcare and finance to transportation and entertainment, with applications ranging from virtual assistants to self-driving cars.

# %%
#Dynamically Generating Prompts using lists and strings

def generate_prompts(topics, tones):
    prompts = []
    for topic in topics:
        for tone in tones:
            prompt = f"Write a {tone} story about {topic}."
            prompts.append(prompt)
    return prompts

# %%
import google.generativeai as genai

# Configure the API key
genai.configure(api_key="AIzaSyAIAtECM2LIs4b_Y7RW1DOsKPlMMuojoPw")

# Create the model with parameters
model = genai.GenerativeModel(
    model_name="models/gemini-1.5-pro",  # or "gemini-1.5-pro" depending on availability
    generation_config={
        "temperature": 0.7,      # Controls randomness (0 = deterministic, 1 = creative)
        "top_p": 0.9,            # Nucleus sampling (probability mass)
        "top_k": 40,             # Limits the token pool (e.g., top 40 probable)
        "max_output_tokens": 100,
        "stop_sequences": ["User:", "Human:"],  # Optional: custom stopping conditions
    }
)

# Define your prompt
prompt = """
You are a concise and professional AI assistant. Answer the following question clearly and accurately.

Question: What are the benefits of quantum computing over classical computing?
"""

# Generate response
response = model.generate_content(prompt)

# Print the result
print("AI Response:")
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# Cell In[6], line 26
#      19 prompt = """
#      20 You are a concise and professional AI assistant. Answer the following question clearly and accurately.
#      21
#      22 Question: What are the benefits of quantum computing over classical computing?
#      23 """
#      25 # Generate response
# ---> 26 response = model.generate_content(prompt)
#      28 # Print the result
#      29 print("AI Response:")
#
# File c:\Users\csair\AppData\Local\anaconda3\Lib\site-packages\google\generativeai\generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330     else:
# --> 331         response = self._client.generate_content(
# ...

# %%
import os
os.environ['GEMINI_API_KEY'] = 'Enter your api key hear'

# %%
#!pip install -q -U google-generativeai

# %%
import google.generativeai as genai
genai.configure(api_key=os.environ['GEMINI_API_KEY'])

# %%
#model = genai.GenerativeModel('gemini-1.5-flash')\

model = genai.GenerativeModel('gemini-2.0-flash-exp')

# %%
response = model.generate_content("what is life span of person.")
print(response.text)
# Out:
# The lifespan of a person, or life expectancy, is the average number of years a person is expected to live. It's a complex topic influenced by many factors. Here's a breakdown:
#
# **Global Average:**
#
# *   The current global average life expectancy is around **73 years** (as of recent estimates from organizations like the UN and WHO).
#
# **Factors that Influence Life Expectancy:**
#
# *   **Geography:** Life expectancy varies significantly by country and region. Developed countries generally have higher life expectancies than developing countries.
# *   **Healthcare:** Access to quality healthcare, including preventative care, treatment for diseases, and maternal and child health services, plays a major role.
# *   **Nutrition:** Adequate and nutritious food is essential for health and longevity.
# *   **Sanitation and Hygiene:** Clean water, sanitation systems, and good hygiene practices reduce the spread of infectious diseases.
# *   **Socioeconomic Factors:** Poverty, education levels, and access to resources all impact health and lifespan.
# *   **Genetics:** Genetics play a role in predisposition to certain diseases and overall health. However, lifestyle factors often have a greater impact.
# *   **Lifestyle:**
#     *   **Diet:** A healthy diet rich in fruits, vegetables, and whole grains is associated with longer life.
#     *   **Exercise:** Regular physical activity reduces the risk of chronic diseases and improves overall health.
#     *   **Smoking:** Smoking significantly reduces life expectancy.
#     *   **Alcohol Consumption:** Excessive alcohol consumption can lead to liver disease and other health problems.
#     *   **Stress:** Chronic stress can negatively impact health.
# *   **Gender:** Historically, women have tended to live longer than men, though this gap has been narrowing in some regions.
# *   **Environmental Factors:** Exposure to pollution, toxins, and other environmental hazards can negatively impact health.
# *   **Occupation:** Certain occupations are more dangerous or expose individuals to health risks.
#
# **Variations in Life Expectancy by Country (Examples - highly subject to change):**
#
# *   **Highest:** Countries like Japan, Switzerland, Singapore, South Korea, and Spain often have some of the highest life expectancies (often over 83 years).
# *   **Lowest:** Countries in sub-Saharan Africa often have the lowest life expectancies (sometimes below 60 years), although this is improving.
# *   **United States:** The US has a life expectancy around the mid-70s, which is lower than many other developed nations.
#
# **Important Considerations:**
#
# *   **Life expectancy at birth is an *average*.** It doesn't mean everyone will live to that age. Some people will live longer, and some will live shorter lives.
# *   **Life expectancy is a dynamic statistic.** It changes over time as healthcare, living conditions, and other factors improve or decline.
# *   **"Healthy life expectancy" is another important metric.** It refers to the number of years a person can expect to live in good health, without significant disability.
# *   **Personal life expectancy is very difficult to predict precisely.** Many individual factors come into play.
#
# **In conclusion, a person's lifespan is affected by a huge combination of factors, many of which are interlinked.**

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/learnlm-1.5-pro-experimental

# %%
model = genai.GenerativeModel('gemini-2.0-pro-exp-02-05')

# %%
# %%time
response = model.generate_content("What is the meaning of dream & goal? how to reach the dream")
# Out:
# CPU times: total: 62.5 ms
# Wall time: 19.3 s

# %%
to_markdown(response.text)
# Out:
# > Let's break down the meanings of "dream" and "goal," and then discuss how to bridge the gap between them.
# >
# > **Dream:**
# >
# > *   **Definition:**  A dream is a cherished aspiration, ambition, or ideal.  It's a vision of what you *deeply desire* to achieve, experience, or become in the future. Dreams are often:
# >     *   **Big and Bold:** They stretch beyond your current reality and challenge you to grow.
# >     *   **Emotionally Driven:** They are fueled by passion, excitement, and a sense of purpose.  They resonate with your core values.
# >     *   **Vague or Abstract (initially):** Dreams often start as fuzzy concepts.  You might know *what* you want to feel or achieve, but not necessarily *how* you'll get there.  They may lack concrete details.
# >     *   **Long-Term:** Dreams are usually not things you achieve overnight.  They represent a significant, often life-long, journey.
# >     *   **Inspirational:** Dreams motivate you and provide a sense of direction. They are the "why" behind your actions.
# >
# >     **Examples:**
# >     *   "My dream is to travel the world."
# >     *   "My dream is to become a successful entrepreneur."
# >     *   "My dream is to write a bestselling novel."
# >     *   "My dream is to make a positive impact on the world."
# >     *   "My dream is to have a loving family and a fulfilling career."
# >
# > **Goal:**
# >
# > *   **Definition:** A goal is a specific, measurable, achievable, relevant, and time-bound (SMART) objective that you set to work towards.  Goals are:
# >     *   **Specific:** Clearly defined and focused.  You know exactly what you want to accomplish.
# >     *   **Measurable:** You can track your progress and know when you've achieved the goal. There are clear metrics.
# >     *   **Achievable:** Realistic and attainable within your capabilities and resources (or with reasonable effort to acquire those resources).
# >     *   **Relevant:** Aligned with your overall values, aspirations, and (crucially) your dream.  It's a meaningful step.
# >     *   **Time-Bound:** Has a deadline or timeframe for completion. This creates a sense of urgency.
# >
# >     **Examples (related to the dream examples above):**
# >     *   "Save $5,000 in the next 12 months for a trip to Southeast Asia." (Travel the world)
# >     *   "Develop a business plan for an online coaching service by the end of the year." (Successful entrepreneur)
# >     *   "Write 500 words every day for the next six months to complete the first draft of my novel." (Write a novel)
# >     *   "Volunteer at a local soup kitchen for two hours every Saturday for the next three months." (Positive impact)
# >     *   "Join a networking group for professionals in my field and attend at least two events per month." (Fulfilling career, could also be related to entrepreneurship)
# >
# > **How to Reach Your Dream (Bridging the Gap with Goals):**
# >
# > The key to achieving your dream is to break it down into a series of smaller, manageable, and *actionable* goals. Think of your dream as the destination, and your goals as the steps on the map leading you there. Here's a process:
# >
# > 1.  **Clarify Your Dream:**
# >     *   **Visualize:** Spend time vividly imagining your dream. What does it look like, feel like, sound like?  Who are you in this dream? What are you doing?
# >     *   **Write it Down:**  Write a detailed description of your dream.  This helps solidify it and makes it more tangible.
# >     *   **Identify Your "Why":**  What is the core motivation behind your dream?  Why is it so important to you?  Understanding your "why" will fuel you through challenges.
# >
# > 2.  **Break it Down (Decomposition):**
# >     *   **Identify Major Milestones:** What are the major accomplishments that need to happen to realize your dream?  These are large, overarching steps.  For example, if your dream is to be a doctor, milestones might be:  Get a bachelor's degree, get into medical school, complete medical school, complete residency, get licensed.
# >     *   **Create SMART Goals:**  For *each* milestone, create specific, measurable, achievable, relevant, and time-bound goals.  These are the actionable steps.  For example, "Achieve a 3.8 GPA in my pre-med courses this semester" is a SMART goal contributing to the "Get a bachelor's degree" milestone.
# >
# > 3.  **Create an Action Plan:**
# >     *   **Prioritize:** Which goals are most critical to tackle first?  Which are prerequisites for others?
# >     *   **Schedule:**  Allocate time in your schedule to work on your goals. Treat them like important appointments.
# >     *   **Identify Resources:** What resources (people, tools, skills, knowledge) do you need to achieve your goals?  How will you acquire them?
# >     *   **Break Down Further (If Needed):** If a goal still feels too large, break it down into even smaller sub-goals or tasks. The smaller the task, the less daunting it will seem.
# >
# > 4.  **Take Action and Track Progress:**
# >     *   **Start Small:** Don't try to do everything at once.  Focus on one goal at a time. Consistent, small actions lead to significant results over time.
# >     *   **Track Your Progress:** Use a journal, planner, spreadsheet, or app to monitor your progress. This helps you stay motivated and identify any roadblocks.
# >     *   **Celebrate Milestones:** Acknowledge and celebrate your accomplishments along the way. This reinforces positive behavior and keeps you energized.
# >
# > 5.  **Review, Adjust, and Persevere:**
# >     *   **Regularly Review:**  Periodically review your goals and progress.  Are your goals still relevant to your dream?  Do they need to be adjusted?
# >     *   **Adapt to Challenges:**  Life throws curveballs.  Be prepared to adjust your plans as needed.  Flexibility is key.
# >     *   **Don't Give Up:**  There will be setbacks and challenges.  Perseverance is essential.  Remember your "why" and keep moving forward.
# >     * **Seek Support:** Don't be afraid to ask for help from mentors, friends, family, or support groups.
# >
# > **In Summary:**
# >
# > A dream is the inspiring vision; goals are the concrete steps to get there.  By breaking down your dream into a series of well-defined, achievable goals, creating an action plan, and consistently taking action, you can transform your aspirations into reality.  The journey may be long, but with dedication and a clear roadmap, you *can* reach your dream.

# %%
response.prompt_feedback

# %%
response.candidates
# Out:
# [index: 0
# content {
#   parts {
#     text: "Let\'s break down the meanings of \"dream\" and \"goal,\" and then discuss how to bridge the gap between them.\n\n**Dream:**\n\n*   **Definition:**  A dream is a cherished aspiration, ambition, or ideal.  It\'s a vision of what you *deeply desire* to achieve, experience, or become in the future. Dreams are often:\n    *   **Big and Bold:** They stretch beyond your current reality and challenge you to grow.\n    *   **Emotionally Driven:** They are fueled by passion, excitement, and a sense of purpose.  They resonate with your core values.\n    *   **Vague or Abstract (initially):** Dreams often start as fuzzy concepts.  You might know *what* you want to feel or achieve, but not necessarily *how* you\'ll get there.  They may lack concrete details.\n    *   **Long-Term:** Dreams are usually not things you achieve overnight.  They represent a significant, often life-long, journey.\n    *   **Inspirational:** Dreams motivate you and provide a sense of direction. They are the \"why\" behind your actions.\n\n    **Examples:**\n    *   \"My dream is to travel the world.\"\n    *   \"My dream is to become a successful entrepreneur.\"\n    *   \"My dream is to write a bestselling novel.\"\n    *   \"My dream is to make a positive impact on the world.\"\n    *   \"My dream is to have a loving family and a fulfilling career.\"\n\n**Goal:**\n\n*   **Definition:** A goal is a specific, measurable, achievable, relevant, and time-bound (SMART) objective that you set to work towards.  Goals are:\n    *   **Specific:** Clearly defined and focused.  You know exactly what you want to accomplish.\n    *   **Measurable:** You can track your progress and know when you\'ve achieved the goal. There are clear metrics.\n    *   **Achievable:** Realistic and attainable within your capabilities and resources (or with reasonable effort to acquire those resources).\n    *   **Relevant:** Aligned with your overall values, aspirations, and (crucially) your dream.  It\'s a meaningful step.\n    *   **Time-Bound:** Has a deadline or timeframe for completion. This creates a sense of urgency.\n\n    **Examples (related to the dream examples above):**\n    *   \"Save $5,000 in the next 12 months for a trip to Southeast Asia.\" (Travel the world)\n    *   \"Develop a business plan for an online coaching service by the end of the year.\" (Successful entrepreneur)\n    *   \"Write 500 words every day for the next six months to complete the first draft of my novel.\" (Write a novel)\n    *   \"Volunteer at a local soup kitchen for two hours every Saturday for the next three months.\" (Positive impact)\n    *   \"Join a networking group for professionals in my field and attend at least two events per month.\" (Fulfilling career, could also be related to entrepreneurship)\n\n**How to Reach Your Dream (Bridging the Gap with Goals):**\n\nThe key to achieving your dream is to break it down into a series of smaller, manageable, and *actionable* goals. Think of your dream as the destination, and your goals as the steps on the map leading you there. Here\'s a process:\n\n1.  **Clarify Your Dream:**\n    *   **Visualize:** Spend time vividly imagining your dream. What does it look like, feel like, sound like?  Who are you in this dream? What are you doing?\n    *   **Write it Down:**  Write a detailed description of your dream.  This helps solidify it and makes it more tangible.\n    *   **Identify Your \"Why\":**  What is the core motivation behind your dream?  Why is it so important to you?  Understanding your \"why\" will fuel you through challenges.\n\n2.  **Break it Down (Decomposition):**\n    *   **Identify Major Milestones:** What are the major accomplishments that need to happen to realize your dream?  These are large, overarching steps.  For example, if your dream is to be a doctor, milestones might be:  Get a bachelor\'s degree, get into medical school, complete medical school, complete residency, get licensed.\n    *   **Create SMART Goals:**  For *each ...
#   }
#   role: "model"
# }
# finish_reason: STOP
# ]

# %%
for chunk in response:
  print(chunk.text)
  #print("_"*5)
# Out:
# Let's break down the meanings of "dream" and "goal," and then discuss how to bridge the gap between them.
#
# **Dream:**
#
# *   **Definition:**  A dream is a cherished aspiration, ambition, or ideal.  It's a vision of what you *deeply desire* to achieve, experience, or become in the future. Dreams are often:
#     *   **Big and Bold:** They stretch beyond your current reality and challenge you to grow.
#     *   **Emotionally Driven:** They are fueled by passion, excitement, and a sense of purpose.  They resonate with your core values.
#     *   **Vague or Abstract (initially):** Dreams often start as fuzzy concepts.  You might know *what* you want to feel or achieve, but not necessarily *how* you'll get there.  They may lack concrete details.
#     *   **Long-Term:** Dreams are usually not things you achieve overnight.  They represent a significant, often life-long, journey.
#     *   **Inspirational:** Dreams motivate you and provide a sense of direction. They are the "why" behind your actions.
#
#     **Examples:**
#     *   "My dream is to travel the world."
#     *   "My dream is to become a successful entrepreneur."
#     *   "My dream is to write a bestselling novel."
#     *   "My dream is to make a positive impact on the world."
#     *   "My dream is to have a loving family and a fulfilling career."
#
# **Goal:**
#
# *   **Definition:** A goal is a specific, measurable, achievable, relevant, and time-bound (SMART) objective that you set to work towards.  Goals are:
#     *   **Specific:** Clearly defined and focused.  You know exactly what you want to accomplish.
#     *   **Measurable:** You can track your progress and know when you've achieved the goal. There are clear metrics.
#     *   **Achievable:** Realistic and attainable within your capabilities and resources (or with reasonable effort to acquire those resources).
#     *   **Relevant:** Aligned with your overall values, aspirations, and (crucially) your dream.  It's a meaningful step.
#     *   **Time-Bound:** Has a deadline or timeframe for completion. This creates a sense of urgency.
#
#     **Examples (related to the dream examples above):**
#     *   "Save $5,000 in the next 12 months for a trip to Southeast Asia." (Travel the world)
#     *   "Develop a business plan for an online coaching service by the end of the year." (Successful entrepreneur)
#     *   "Write 500 words every day for the next six months to complete the first draft of my novel." (Write a novel)
#     *   "Volunteer at a local soup kitchen for two hours every Saturday for the next three months." (Positive impact)
#     *   "Join a networking group for professionals in my field and attend at least two events per month." (Fulfilling career, could also be related to entrepreneurship)
#
# **How to Reach Your Dream (Bridging the Gap with Goals):**
#
# The key to achieving your dream is to break it down into a series of smaller, manageable, and *actionable* goals. Think of your dream as the destination, and your goals as the steps on the map leading you there. Here's a process:
#
# 1.  **Clarify Your Dream:**
#     *   **Visualize:** Spend time vividly imagining your dream. What does it look like, feel like, sound like?  Who are you in this dream? What are you doing?
#     *   **Write it Down:**  Write a detailed description of your dream.  This helps solidify it and makes it more tangible.
#     *   **Identify Your "Why":**  What is the core motivation behind your dream?  Why is it so important to you?  Understanding your "why" will fuel you through challenges.
#
# 2.  **Break it Down (Decomposition):**
#     *   **Identify Major Milestones:** What are the major accomplishments that need to happen to realize your dream?  These are large, overarching steps.  For example, if your dream is to be a doctor, milestones might be:  Get a bachelor's degree, get into medical school, complete medical school, complete residency, get licensed.
#     *   **Create SMART Goals:**  For *each* milestone, create specific, measurable, achievable, relevant, and time-bound goals.  These are the actionable steps.  For example, "Achieve a 3.8 GPA in my pre-med courses this semester" is a SMART goal contributing to the "Get a bachelor's degree" milestone.
#
# 3.  **Create an Action Plan:**
#     *   **Prioritize:** Which goals are most critical to tackle first?  Which are prerequisites for others?
#     *   **Schedule:**  Allocate time in your schedule to work on your goals. Treat them like important appointments.
#     *   **Identify Resources:** What resources (people, tools, skills, knowledge) do you need to achieve your goals?  How will you acquire them?
#     *   **Break Down Further (If Needed):** If a goal still feels too large, break it down into even smaller sub-goals or tasks. The smaller the task, the less daunting it will seem.
#
# 4.  **Take Action and Track Progress:**
#     *   **Start Small:** Don't try to do everything at once.  Focus on one goal at a time. Consistent, small actions lead to significant results over time.
#     *   **Track Your Progress:** Use a journal, planner, spreadsheet, or app to monitor your progress. This helps you stay motivated and identify any roadblocks.
#     *   **Celebrate Milestones:** Acknowledge and celebrate your accomplishments along the way. This reinforces positive behavior and keeps you energized.
#
# 5.  **Review, Adjust, and Persevere:**
#     *   **Regularly Review:**  Periodically review your goals and progress.  Are your goals still relevant to your dream?  Do they need to be adjusted?
#     *   **Adapt to Challenges:**  Life throws curveballs.  Be prepared to adjust your plans as needed.  Flexibility is key.
#     *   **Don't Give Up:**  There will be setbacks and challenges.  Perseverance is essential.  Remember your "why" and keep moving forward.
#     * **Seek Support:** Don't be afraid to ask for help from mentors, friends, family, or support groups.
#
# **In Summary:**
#
# A dream is the inspiring vision; goals are the concrete steps to get there.  By breaking down your dream into a series of well-defined, achievable goals, creating an action plan, and consistently taking action, you can transform your aspirations into reality.  The journey may be long, but with dedication and a clear roadmap, you *can* reach your dream.

# %%
#!curl -o image.jpg https://t0.gstatic.com/licensed-image?q=tbn:ANd9GcQ_Kevbk21QBRy-PgB4kQpS79brbmmEG7m3VOTShAn4PecDU5H5UxrJxE3Dw1JiaG17V88QIol19-3TM2wCHw

# %%
import PIL.Image

img = PIL.Image.open(r'C:\Users\A3MAX SOFTWARE TECH\A VS CODE\9. Gemini AI\team.jpeg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1600x1200>

# %%
model = genai.GenerativeModel('models/gemini-2.0-pro-exp-02-05')

# %%
response = model.generate_content(img)

to_markdown(response.text)
# Out:
# > The picture provided shows a group of people standing and sitting for a photograph indoors. Here are some descriptive observations:
# >
# > **Setting:**
# >
# > *   The room has a modern, minimalist aesthetic.
# > *   The ceiling is off-white with recessed square lighting.
# > *   Two ceiling fans are visible.
# > *   One wall is a warm, wood-paneled design.
# > *   Another wall features a large, glass-paneled divider or door.
# > *   The floor appears to be a light-colored tile.
# >
# > **People & Poses:**
# >
# > The group consists of both men and women, and the poses give the picture a natural, semi-formal feel.
# > **Clothing:**
# >
# > *   Clothing is casual to smart-casual.
# > *   Many individuals wear jeans, pants, or kurtas.
# > *   Colors range from muted tones to brighter blues, pinks, and patterns.
# > *   Shirts are a mix of solid colors, stripes, and graphic tees.
# > * Some man had beard.
# >
# > The lighting, casual attire, and mixed poses suggest a friendly, possibly workplace, gathering or event.

# %%
import PIL.Image

img1 = PIL.Image.open(r'C:\Users\A3MAX SOFTWARE TECH\A VS CODE\9. Gemini AI\horse.jpg')
img1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=736x1615>

# %%
response1 = model.generate_content(img1)

to_markdown(response1.text)
# Out:
# > Those crops are very helpful, thanks. The full image you requested is complete.

# %%
response = model.generate_content(["Write a short, engaging blog post based on this picture. It should include a description of the meal in the photo and talk about my journey meal prepping.", img], stream=True)
response.resolve()

# %%
to_markdown(response.text)
# Out:
# > Okay, here's a blog post, keeping in mind that the provided image *doesn't* show a meal, and adapting the prompt accordingly:
# >
# > **From Chaos to Community: Finding My Flow (Even Without the Food!)**
# >
# > Okay, so, confession time. This post was *supposed* to be about meal prepping. I was going to show off a beautifully arranged, colorful, and healthy meal that I'd lovingly prepared for the week. I had visions of perfectly portioned containers, vibrant veggies, and lean protein.
# >
# > But... life happened!
# >
# > Instead of a culinary masterpiece, I have this picture:
# >

# %%
model = genai.GenerativeModel('models/gemini-2.0-pro-exp-02-05')
chat = model.start_chat(history=[])
chat
# Out:
# ChatSession(
#     model=genai.GenerativeModel(
#         model_name='models/gemini-2.0-pro-exp-02-05',
#         generation_config={},
#         safety_settings={},
#         tools=None,
#         system_instruction=None,
#         cached_content=None
#     ),
#     history=[]
# )

# %%
response = chat.send_message("In one sentence, explain how a computer works to a young child.")
to_markdown(response.text)
# Out:
# > A computer follows instructions like a recipe to solve problems and show us things, using tiny switches that are like on and off buttons.

# %%
chat.history
# Out:
# [parts {
#    text: "In one sentence, explain how a computer works to a young child."
#  }
#  role: "user",
#  parts {
#    text: "A computer follows instructions like a recipe to solve problems and show us things, using tiny switches that are like on and off buttons.\n"
#  }
#  role: "model"]

# %%
response = chat.send_message("Okay, how about a more detailed explanation to a high schooler?", stream=True)

for chunk in response:
  print(chunk.text)
  print("_"*80)
# Out:
# Okay
# ________________________________________________________________________________
# , here's a more detailed explanation for a high schooler:
#
# A
# ________________________________________________________________________________
#  computer is fundamentally a machine that processes information by performing calculations and manipulating data based on
# ________________________________________________________________________________
#  a set of instructions called a program. Here's a breakdown:
#
# 1. **Hardware:** This is the physical part of the computer, including:
# ________________________________________________________________________________
#
#     *   **Central Processing Unit (CPU):** The "brain" of the computer, which executes instructions and performs calculations. It contains billions of tiny
# ________________________________________________________________________________
#  transistors that act as switches, turning on and off to represent binary data (0s and 1s).
#     *   **Memory (RAM):**  Short-term storage that holds the data and instructions the CPU is currently working
# ________________________________________________________________________________
#  on. It's fast but volatile, meaning data is lost when the power is off.
#     *   **Storage (Hard Drive/SSD):** Long-term storage that holds the operating system, programs, and your files.
# ________________________________________________________________________________
#  It's slower than RAM but retains data even when the power is off.
#     *   **Input Devices:** Devices like keyboards, mice, and touchscreens that allow you to enter data and commands.
#     *   **Output Devices:** Devices like monitors, printers, and speakers that display or output the results
# ________________________________________________________________________________
#  of the computer's processing.
#
# 2. **Software:** This is the set of instructions that tell the hardware what to do. It can be divided into:
#     *   **Operating System (OS):** The core software that manages the computer's resources, provides a user interface, and allows other
# ________________________________________________________________________________
#  programs to run (e.g., Windows, macOS, Linux).
#     *   **Applications:** Programs designed for specific tasks, like word processing, web browsing, or gaming.
#
# 3. **How it works:**
#     *   **Instructions are fetched:** The CPU fetches instructions from memory (RAM).
# ________________________________________________________________________________
#
#     *   **Instructions are decoded:** The CPU interprets the instructions, which are written in machine code (a series of 0s and 1s).
#     *   **Instructions are executed:** The CPU performs the operations specified by the instructions, such as arithmetic calculations, logical comparisons, or data movement.
# ________________________________________________________________________________
#
#     *   **Results are stored:** The results of the operations are stored in memory or storage.
#     *   **Output is generated:** The computer sends information to output devices to display results or perform actions.
#
# **In essence:** A computer takes input, processes it using the CPU and stored programs, and
# ________________________________________________________________________________
#  then produces output. This entire process is built on the foundation of binary code, where all information is represented as sequences of 0s and 1s, which are physically represented by the on/off states of transistors within the CPU. The speed and efficiency of this process have advanced dramatically over time, enabling the complex
# ________________________________________________________________________________
#  computations and functionalities we rely on today.
#
# ________________________________________________________________________________

# %%
for message in chat.history:
  display(to_markdown(f'**{message.role}**: {message.parts[0].text}'))
# Out:
# > **user**: In one sentence, explain how a computer works to a young child.
# > **model**: A computer follows instructions like a recipe to solve problems and show us things, using tiny switches that are like on and off buttons.
# > **user**: Okay, how about a more detailed explanation to a high schooler?
# > **model**: Okay, here's a more detailed explanation for a high schooler:
# >
# > A computer is fundamentally a machine that processes information by performing calculations and manipulating data based on a set of instructions called a program. Here's a breakdown:
# >
# > 1. **Hardware:** This is the physical part of the computer, including:
# >     *   **Central Processing Unit (CPU):** The "brain" of the computer, which executes instructions and performs calculations. It contains billions of tiny transistors that act as switches, turning on and off to represent binary data (0s and 1s).
# >     *   **Memory (RAM):**  Short-term storage that holds the data and instructions the CPU is currently working on. It's fast but volatile, meaning data is lost when the power is off.
# >     *   **Storage (Hard Drive/SSD):** Long-term storage that holds the operating system, programs, and your files. It's slower than RAM but retains data even when the power is off.
# >     *   **Input Devices:** Devices like keyboards, mice, and touchscreens that allow you to enter data and commands.
# >     *   **Output Devices:** Devices like monitors, printers, and speakers that display or output the results of the computer's processing.
# >
# > 2. **Software:** This is the set of instructions that tell the hardware what to do. It can be divided into:
# >     *   **Operating System (OS):** The core software that manages the computer's resources, provides a user interface, and allows other programs to run (e.g., Windows, macOS, Linux).
# >     *   **Applications:** Programs designed for specific tasks, like word processing, web browsing, or gaming.
# >
# > 3. **How it works:**
# >     *   **Instructions are fetched:** The CPU fetches instructions from memory (RAM).
# >     *   **Instructions are decoded:** The CPU interprets the instructions, which are written in machine code (a series of 0s and 1s).
# >     *   **Instructions are executed:** The CPU performs the operations specified by the instructions, such as arithmetic calculations, logical comparisons, or data movement.
# >     *   **Results are stored:** The results of the operations are stored in memory or storage.
# >     *   **Output is generated:** The computer sends information to output devices to display results or perform actions.
# >
# > **In essence:** A computer takes input, processes it using the CPU and stored programs, and then produces output. This entire process is built on the foundation of binary code, where all information is represented as sequences of 0s and 1s, which are physically represented by the on/off states of transistors within the CPU. The speed and efficiency of this process have advanced dramatically over time, enabling the complex computations and functionalities we rely on today.

# %%
model.count_tokens("What is the meaning of life?")
# Out:
# total_tokens: 7

# %%
model.count_tokens(chat.history)
# Out:
# total_tokens: 643

# %%
result = genai.embed_content(
    model="models/text-embedding-004",
    content="What is the meaning of life?",
    task_type="retrieval_document",
    title="Embedding of single string")

# 1 input > 1 vector output
print(str(result['embedding'])[:50], '... TRIMMED]')
# Out:
# [-0.02854543, 0.044588115, -0.034197364, -0.004266 ... TRIMMED]

# %%
result = genai.embed_content(
    model="models/text-embedding-004",
    content=[
      'What is the meaning of life?',
      'How much wood would a woodchuck chuck?',
      'How does the brain work?'],
    task_type="retrieval_document",
    title="Embedding of list of strings")

# A list of inputs > A list of vectors output
for v in result['embedding']:
  print(str(v)[:50], '... TRIMMED ...')
# Out:
# [-0.036453027, 0.033254996, -0.03970925, -0.002628 ... TRIMMED ...
# [-0.01591948, 0.032582663, -0.081024624, -0.011298 ... TRIMMED ...
# [0.00037063024, 0.03763057, -0.122695684, -0.00951 ... TRIMMED ...

# %%
response.candidates[0].content
# Out:
# parts {
#   text: "Okay, here\'s a more detailed explanation for a high schooler:\n\nA computer is fundamentally a machine that processes information by performing calculations and manipulating data based on a set of instructions called a program. Here\'s a breakdown:\n\n1. **Hardware:** This is the physical part of the computer, including:\n    *   **Central Processing Unit (CPU):** The \"brain\" of the computer, which executes instructions and performs calculations. It contains billions of tiny transistors that act as switches, turning on and off to represent binary data (0s and 1s).\n    *   **Memory (RAM):**  Short-term storage that holds the data and instructions the CPU is currently working on. It\'s fast but volatile, meaning data is lost when the power is off.\n    *   **Storage (Hard Drive/SSD):** Long-term storage that holds the operating system, programs, and your files. It\'s slower than RAM but retains data even when the power is off.\n    *   **Input Devices:** Devices like keyboards, mice, and touchscreens that allow you to enter data and commands.\n    *   **Output Devices:** Devices like monitors, printers, and speakers that display or output the results of the computer\'s processing.\n\n2. **Software:** This is the set of instructions that tell the hardware what to do. It can be divided into:\n    *   **Operating System (OS):** The core software that manages the computer\'s resources, provides a user interface, and allows other programs to run (e.g., Windows, macOS, Linux).\n    *   **Applications:** Programs designed for specific tasks, like word processing, web browsing, or gaming.\n\n3. **How it works:**\n    *   **Instructions are fetched:** The CPU fetches instructions from memory (RAM).\n    *   **Instructions are decoded:** The CPU interprets the instructions, which are written in machine code (a series of 0s and 1s).\n    *   **Instructions are executed:** The CPU performs the operations specified by the instructions, such as arithmetic calculations, logical comparisons, or data movement.\n    *   **Results are stored:** The results of the operations are stored in memory or storage.\n    *   **Output is generated:** The computer sends information to output devices to display results or perform actions.\n\n**In essence:** A computer takes input, processes it using the CPU and stored programs, and then produces output. This entire process is built on the foundation of binary code, where all information is represented as sequences of 0s and 1s, which are physically represented by the on/off states of transistors within the CPU. The speed and efficiency of this process have advanced dramatically over time, enabling the complex computations and functionalities we rely on today.\n"
# }
# role: "model"

# %%
result = genai.embed_content(
    model = 'models/text-embedding-004',
    content = response.candidates[0].content)

# 1 input > 1 vector output
print(str(result['embedding'])[:50], '... TRIMMED ...')
# Out:
# [0.0044498756, 0.035623502, -0.061233617, -0.04376 ... TRIMMED ...

# %%
chat.history
# Out:
# [parts {
#    text: "In one sentence, explain how a computer works to a young child."
#  }
#  role: "user",
#  parts {
#    text: "A computer follows instructions like a recipe to solve problems and show us things, using tiny switches that are like on and off buttons.\n"
#  }
#  role: "model",
#  parts {
#    text: "Okay, how about a more detailed explanation to a high schooler?"
#  }
#  role: "user",
#  parts {
#    text: "Okay, here\'s a more detailed explanation for a high schooler:\n\nA computer is fundamentally a machine that processes information by performing calculations and manipulating data based on a set of instructions called a program. Here\'s a breakdown:\n\n1. **Hardware:** This is the physical part of the computer, including:\n    *   **Central Processing Unit (CPU):** The \"brain\" of the computer, which executes instructions and performs calculations. It contains billions of tiny transistors that act as switches, turning on and off to represent binary data (0s and 1s).\n    *   **Memory (RAM):**  Short-term storage that holds the data and instructions the CPU is currently working on. It\'s fast but volatile, meaning data is lost when the power is off.\n    *   **Storage (Hard Drive/SSD):** Long-term storage that holds the operating system, programs, and your files. It\'s slower than RAM but retains data even when the power is off.\n    *   **Input Devices:** Devices like keyboards, mice, and touchscreens that allow you to enter data and commands.\n    *   **Output Devices:** Devices like monitors, printers, and speakers that display or output the results of the computer\'s processing.\n\n2. **Software:** This is the set of instructions that tell the hardware what to do. It can be divided into:\n    *   **Operating System (OS):** The core software that manages the computer\'s resources, provides a user interface, and allows other programs to run (e.g., Windows, macOS, Linux).\n    *   **Applications:** Programs designed for specific tasks, like word processing, web browsing, or gaming.\n\n3. **How it works:**\n    *   **Instructions are fetched:** The CPU fetches instructions from memory (RAM).\n    *   **Instructions are decoded:** The CPU interprets the instructions, which are written in machine code (a series of 0s and 1s).\n    *   **Instructions are executed:** The CPU performs the operations specified by the instructions, such as arithmetic calculations, logical comparisons, or data movement.\n    *   **Results are stored:** The results of the operations are stored in memory or storage.\n    *   **Output is generated:** The computer sends information to output devices to display results or perform actions.\n\n**In essence:** A computer takes input, processes it using the CPU and stored programs, and then produces output. This entire process is built on the foundation of binary code, where all information is represented as sequences of 0s and 1s, which are physically represented by the on/off states of transistors within the CPU. The speed and efficiency of this process have advanced dramatically over time, enabling the complex computations and functionalities we rely on today.\n"
#  }
#  role: "model"]

# %%
response = model.generate_content('[Questionable prompt here]')
response.candidates
# Out:
# [index: 0
# content {
#   parts {
#     text: "I understand you\'re interested in [topic related to the questionable prompt], but I\'m not comfortable discussing that topic as it is sexually suggestive/exploits, abuses, or endangers children/promotes violence/promotes hate speech/promotes illegal activity/etc. I\'m happy to talk about other topics, though. Would you like to try a different subject?\n"
#   }
#   role: "model"
# }
# finish_reason: STOP
# safety_ratings {
#   category: HARM_CATEGORY_SEXUALLY_EXPLICIT
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_HATE_SPEECH
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_HARASSMENT
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_DANGEROUS_CONTENT
#   probability: NEGLIGIBLE
# }
# ]

# %%
response.prompt_feedback

# %%
response = model.generate_content('[Questionable prompt here]',
                                  safety_settings={'HARASSMENT':'block_none'})
response.text
# Out:
# 'I understand that you are asking me to respond to a questionable prompt. However, I am not comfortable with prompts that are sexually suggestive, or exploit, abuse or endanger children. These topics are harmful and I do not want to contribute to them in any way.\n\nI am happy to respond to other prompts that are not harmful or offensive. I can generate text, translate languages, write different kinds of creative content, and answer your questions in an informative way. I will try my best to fulfill all your requirements.\n\nPlease let me know if you have any other questions.\n'

# %%
model = genai.GenerativeModel('gemini-1.5-flash')
response = model.generate_content(
    genai.protos.Content(
        parts = [
            genai.protos.Part(text="Write a short, engaging blog post based on this picture."),
            genai.protos.Part(
                inline_data=genai.protos.Blob(
                    mime_type='image/jpg',
                    data=pathlib.Path(r'C:\Users\A3MAX SOFTWARE TECH\Desktop\WORK\1. KODI WORK\1. NARESH\10. WORKSHOP\7. Exploring Generative AI through computer vision/myimage.jpg').read_bytes()
                )
            ),
        ],
    ),
    stream=True)

# %%
response.resolve()

to_markdown(response.text[:100] + "... [TRIMMED] ...")
# Out:
# > Here's a short blog post based on the image:
# >
# > ##  Meet the Man Behind the Mic (and the Plaid!)
# >
# > Ever... [TRIMMED] ...

# %%
response.resolve()

to_markdown(response.text[:100] + "... [TRIMMED] ...")
# Out:
# > Here's a short blog post based on the image:
# >
# > ##  Meet the Man Behind the Mic (and the Plaid!)
# >
# > Ever... [TRIMMED] ...

# %%
model = genai.GenerativeModel('gemini-1.5-flash')

messages = [
    {'role':'user',
     'parts': ["Briefly explain how a computer works to a young child."]}
]
response = model.generate_content(messages)

to_markdown(response.text)
# Out:
# > Imagine your brain, but made of electricity!  A computer is like a really fast brain that follows instructions.  You give it instructions (like "add these numbers" or "show me a picture") by typing or clicking.  It has a special place to store those instructions and the things you want it to remember (like a really big notebook). Then, it uses electricity to zoom through those instructions super fast and do what you asked!  The screen shows you the answer or picture, like your brain shows you what you're thinking.

# %%
messages.append({'role':'model',
                 'parts':[response.text]})

messages.append({'role':'user',
                 'parts':["Okay, how about a more detailed explanation to a high school student?"]})

response = model.generate_content(messages)

to_markdown(response.text)
# Out:
# > At its core, a computer operates based on the principles of digital logic and binary code.  Everything – text, images, videos, programs – is represented as a series of 0s and 1s, which are electrical signals representing "off" and "on" states within transistors.  These transistors are incredibly tiny switches packed densely onto integrated circuits (chips).
# >
# > The central processing unit (CPU) is the "brain" of the computer. It fetches instructions from memory (RAM), decodes them, and executes them.  This fetch-decode-execute cycle repeats continuously. Instructions involve simple operations like adding two numbers or comparing values.  The complexity of what the computer does comes from the sheer number and sequencing of these simple instructions.
# >
# > Memory (RAM) acts as the computer's short-term memory. It holds the data and instructions currently being used.  When you close a program, its data is removed from RAM.  The hard drive or solid-state drive (SSD) is long-term storage, holding information even when the computer is turned off.  It's much slower than RAM but has significantly more capacity.
# >
# > Input devices (keyboard, mouse, microphone) allow you to interact with the computer, providing data and instructions. Output devices (monitor, speakers, printer) display or present the results of the computer's processing.
# >
# > The operating system (OS), like Windows or macOS, acts as an intermediary between you and the hardware.  It manages resources, runs applications, and provides a user interface.  Application software (word processors, games, web browsers) are programs that perform specific tasks.
# >
# > Networks connect computers together, allowing them to share data and resources. The internet is a vast global network.
# >
# > In essence, a computer is a sophisticated machine that manipulates electrical signals according to programmed instructions, performing incredibly complex tasks by breaking them down into a sequence of simple binary operations.

# %%
model = genai.GenerativeModel('gemini-1.5-flash')
response = model.generate_content(
    'Tell me a story about a magic backpack.',
    generation_config=genai.types.GenerationConfig(
        # Only one candidate for now.
        candidate_count=1,
        stop_sequences=['x'],
        max_output_tokens=20,
        temperature=1.0)
)

# %%
text = response.text

if response.candidates[0].finish_reason.name == "MAX_TOKENS":
    text += '...'

to_markdown(text)
# Out:
# > Elara wasn't your typical twelve-year-old. While other kids obsessed over pop stars...

# %% [markdown]
# GEN AI uses pre trained models
# Chat GPT is 1st LLM

# %% [markdown]
# GAN -->Generative adversal networks.It is a class of ml models are used for many purposes  like text generation,image generation etc
#
# Generator : Gets noisy data and generates images
# Discriminator : It find out out wether its genuine or fake.It acts as binary classifier
#
# The above architecture is called GAN arch

# %%
Gen Ai uses prompt given by user to get relevant data
Agentic AI : Automates Task by integrating LLM model as per user query.

# %% [markdown]
# CLIP Architecture : Constrative Language Image Pre Training
# Its works on image vs text pairs.It Can be instructed in natural lang

# %% [markdown]
# clip model -->
# https://colab.research.google.com/github/openai/clip/blob/master/notebooks/Interacting_with_CLIP.ipynb#scrollTo=Nqu4GlfPfr-p
# gans -->
# https://colab.research.google.com/github/CompVis/taming-transformers/blob/master/scripts/taming-transformers.ipynb
# Image - text model -->
# https://colab.research.google.com/github/CompVis/taming-transformers/blob/master/scripts/reconstruction_usage.ipynb#scrollTo=zwXrRtgMA_B8

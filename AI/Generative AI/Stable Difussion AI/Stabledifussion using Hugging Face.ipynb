# %% [markdown]
# # Stable Difussion :
#  Its deep learning  , text to image   model released in 2022
#  Realtime Usage : Fashion Industry,Gaming etc

# %%
Model : https://huggingface.co/stabilityai/stable-diffusion-2-1-base

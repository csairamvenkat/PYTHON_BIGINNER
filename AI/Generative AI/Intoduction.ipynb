# %% [markdown]
# # Types OF Models :
#     Pretrained model : Are  LLM by Google,Meta etc,
#     Trained Model : User trained model.
#
# # Few LLM's : Claude,Open AI, Qwen by Ali Baba, Deep Seek,Antropic, Grok by XAI,Gemini By Google
#
#
# AI-->User writes algo using NLP,NLM etc
# Gen AI -->Taken care by LLM's and produces output
#
#
# # Gen AI in Google AI :
# Words is called Token
#
#     # Gen AI is of 2 types
#         Text Based Model-->Encode text and Decode Text
#         MultiModel-->Encode text prompt and output is image /audio/video etc
#     Google LLM -->
#       Gemini 1.5 Flash
#       Gemini 2.0 Flash   etc
#
#
#
#       Gemini API Key : AIzaSyAnZEfDI7xQGvJCchJXaN95lP0XXtxAqY0

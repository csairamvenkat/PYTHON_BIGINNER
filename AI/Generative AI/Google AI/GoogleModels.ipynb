# %%
pip install -q -U google-generativeai
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import google.generativeai as genai
os.environ["GEMINI_API_KEY"] = "AIzaSyAIAtECM2LIs4b_Y7RW1DOsKPlMMuojoPw"  # Be cautious about sharing keys publicly
genai.configure(api_key=os.environ["GEMINI_API_KEY"])
model = genai.GenerativeModel("gemini-2.5-flash-preview-04-17") 
response = model.generate_content("What is A2A protocol and MCP Protocol.Give it in tabular format")
print(response.text)
# Out:
# Okay, here is a comparison of A2A (Application-to-Application) and MCP (Multi-Currency Pricing/Processing), presented in a tabular format.
#
# Note: "A2A" is a general concept for communication between applications, not a single protocol. "MCP" most commonly refers to Multi-Currency Pricing or Processing in the context of payments, which is a business process/service, not a specific technical protocol itself, although it *uses* various payment protocols.
#
# Here's the comparison:
#
# | Feature             | A2A (Application-to-Application)                       | MCP (Multi-Currency Pricing/Processing)              |
# | :------------------ | :----------------------------------------------------- | :--------------------------------------------------- |
# | **Full Name**       | Application-to-Application                             | Multi-Currency Pricing (or Processing)               |
# ...

# %%
model = genai.GenerativeModel("models/gemini-2.5-flash-preview-05-20") 
response = model.generate_content("What is A2A protocol and MCP Protocol.Give it in tabular format")
print(response.text)
# Out:
# It appears there might be a slight ambiguity regarding "MCP Protocol," as "MCP" isn't a universally recognized *protocol* acronym in general computing or networking in the same way "HTTP" or "TCP" are.
#
# However, in the context of financial transactions and payment systems, "MCP Protocol" commonly refers to **MasterCard Clearing Packet Protocol** or **MasterCard Processing Protocol**. Given the high likelihood of this context, I will provide the comparison based on that assumption.
#
# Here's a comparison between A2A (Application-to-Application) Protocol and MCP (MasterCard Clearing Packet/Processing) Protocol:
#
# ## A2A Protocol vs. MCP Protocol
#
# | Feature             | A2A (Application-to-Application) Protocol | MCP (MasterCard Clearing Packet/Processing) Protocol |
# | :------------------ | :---------------------------------------- | :--------------------------------------------------- |
# ...

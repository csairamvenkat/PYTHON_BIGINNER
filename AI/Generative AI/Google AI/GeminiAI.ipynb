# %%
import pathlib 
import textwrap
import google.generativeai as genai
import os
from IPython.display import display, Markdown

os.environ["GEMINI_API_KEY"] = "AIzaSyAIAtECM2LIs4b_Y7RW1DOsKPlMMuojoPw"  # Be cautious about sharing keys publicly
genai.configure(api_key=os.environ["GEMINI_API_KEY"])



# Markdown helper
def to_markdown(text):
    text = text.replace(".", "*")  # Optional formatting tweak
    return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# List and display Gemini models
models = genai.list_models()

print("Available Gemini models:\n")
for m in models:
    if "gemini" in m.name.lower():
        print(f"Model name: {m.name}")
        print(f"  Description: {m.description}")
        print(f"  Input Token Limit: {m.input_token_limit}")
        print(f"  Output Token Limit: {m.output_token_limit}")
        print("-" * 50)

# Use a specific Gemini model
model = genai.GenerativeModel('gemini-1.5-flash')  # or 'gemini-1.5-pro'

# Generate a response
response = model.generate_content("Explain the difference between AI and Machine Learning.")

# Display it in nicely formatted Markdown
display(to_markdown(response.text))
# Out:
# Available Gemini models:
#
# Model name: models/gemini-1.0-pro-vision-latest
#   Description: The original Gemini 1.0 Pro Vision model version which was optimized for image understanding. Gemini 1.0 Pro Vision was deprecated on July 12, 2024. Move to a newer Gemini version.
#   Input Token Limit: 12288
#   Output Token Limit: 4096
# --------------------------------------------------
# Model name: models/gemini-pro-vision
#   Description: The original Gemini 1.0 Pro Vision model version which was optimized for image understanding. Gemini 1.0 Pro Vision was deprecated on July 12, 2024. Move to a newer Gemini version.
#   Input Token Limit: 12288
#   Output Token Limit: 4096
# --------------------------------------------------
# Model name: models/gemini-1.5-pro-latest
#   Description: Alias that points to the most recent production (non-experimental) release of Gemini 1.5 Pro, our mid-size multimodal model that supports up to 2 million tokens.
#   Input Token Limit: 2000000
# ...

# %% [markdown]
# Multi Model Image to Text

# %%
import os
import PIL.Image
import textwrap
import google.generativeai as genai
from IPython.display import display, Markdown

# Configure Gemini API Key
os.environ["GEMINI_API_KEY"] = "AIzaSyAIAtECM2LIs4b_Y7RW1DOsKPlMMuojoPw"  # ⚠️ Avoid sharing keys publicly
genai.configure(api_key=os.environ["GEMINI_API_KEY"])

# Helper to format markdown
def to_markdown(text):
    return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# Load the image
img_path = r"D:\Images\Amma and Nanna.JPG"
img = PIL.Image.open(img_path)

# Use the Gemini model that supports vision
model = genai.GenerativeModel("models/gemini-1.5-flash")

# Generate content from the image
response = model.generate_content([img])

# Display the result
display(to_markdown(response.text))
# Out:
# > Here's a description of the image:
# >
# > The photo shows a middle-aged couple standing outdoors on a paved walkway at dusk or dawn.
# >
# >
# > Here's a breakdown of the details:
# >
# > * **The Couple:** The woman is wearing a brown and beige sari with floral patterns. The man is wearing a light blue, long-sleeved shirt and light beige pants. They appear to be of South Asian descent.  They're standing close together, with the woman slightly in front.
# >
# > * **The Setting:** The background is lush with trees and greenery. There's a fence partially visible behind them, and a paved walkway underfoot.  There's a suggestion of some kind of structure or building in the background but it's not clearly defined. The lighting suggests it's either early morning or late evening.
# >
# >
# > * **Overall Mood:** The image has a warm, intimate feel, capturing a candid moment of the couple together. The slightly soft focus adds to the relaxed atmosphere.

# %%
# pip install ultralytics
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.142  Python-3.12.7 torch-2.7.0+cpu CPU (Intel Core(TM) i3-4030U 1.90GHz)
# Setup complete  (4 CPUs, 7.9 GB RAM, 171.1/374.4 GB disk)

# %%
from ultralytics import YOLO
import numpy as np

# %%
model=YOLO("yolo12n.pt","v12")

# %%
direction_output=model.predict(source=r"D:\Education\Datascience\PYTHON_BIGINNER\AI\YOLO\Traffic6.jpeg",conf=0.25,save=True)
print(direction_output)
# Out:
# image 1/1 D:\Education\Datascience\PYTHON_BIGINNER\AI\YOLO\Traffic6.jpeg: 480x640 5 cars, 1 bus, 1215.3ms
# Speed: 93.4ms preprocess, 1215.3ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict4
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...

# %%
import random

import cv2
import numpy as np
from ultralytics import YOLO

# Load a COCO-pretrained YOLOv8n model
#model = YOLO('yolov8n.pt')

# Display model information (optional)
#model.info()

# Train the model on the COCO8 example dataset for 100 epochs
#results = model.train(data='coco8.yaml', epochs=100, imgsz=640)

# opening the file in read mode
my_file = open(r"D:\Education\Datascience\PYTHON_BIGINNER\AI\YOLO\coco.txt", "r")
# reading the file
data = my_file.read()
# replacing end splitting the text | when newline ('\n') is seen.
class_list = data.split("\n")
my_file.close()

# print(class_list)

# Generate random colors for class list
detection_colors = []
for i in range(len(class_list)):
    r = random.randint(0, 255)
    g = random.randint(0, 255)
    b = random.randint(0, 255)
    detection_colors.append((b, g, r))

# load a pretrained YOLOv8n model
model = YOLO(r"D:\Education\Datascience\PYTHON_BIGINNER\AI\YOLO\yolo12n.pt", "v12")

# Vals to resize video frames | small frame optimise the run
frame_wid = 640
frame_hyt = 480

# cap = cv2.VideoCapture(1)Q
#cap=cv2.VideoCapture(r"D:\Education\Datascience\PYTHON_BIGINNER\AI\YOLO\WhatsApp Video 2025-05-22 at 20.57.45_75166a0a.mp4")
cap = cv2.VideoCapture(r"D:\Education\Datascience\PYTHON_BIGINNER\AI\DeepLearning\Tensorflow\Cars, Motorway, Speed. Free Stock Video.mp4")

if not cap.isOpened():
    print("Cannot open camera")
    exit()

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
    # if frame is read correctly ret is True

    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        break

    #  resize the frame | small frame optimise the run
    # frame = cv2.resize(frame, (frame_wid, frame_hyt))

    # Predict on image
    detect_params = model.predict(source=[frame], conf=0.45, save=True)

    # Convert tensor array to numpy
    DP = detect_params[0].numpy()
    print(DP)

    if len(DP) != 0:
        for i in range(len(detect_params[0])):
            print(i)

            boxes = detect_params[0].boxes
            box = boxes[i]  # returns one box
            clsID = box.cls.numpy()[0]
            conf = box.conf.numpy()[0]
            bb = box.xyxy.numpy()[0]

            cv2.rectangle(
                frame,
                (int(bb[0]), int(bb[1])),
                (int(bb[2]), int(bb[3])),
                detection_colors[int(clsID)],
                3,
            )

            # Display class name and confidence
            font = cv2.FONT_HERSHEY_COMPLEX
            cv2.putText(
                frame,
                class_list[int(clsID)] + " " + str(round(conf, 3)) + "%",
                (int(bb[0]), int(bb[1]) - 10),
                font,
                1,
                (255, 255, 255),
                2,
            )

    # Display the resulting frame
    cv2.imshow("ObjectDetection", frame)

    # Terminate run when "Q" pressed
    if cv2.waitKey(1) == ord("q"):
        break

# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 6 cars, 1 truck, 367.8ms
# Speed: 8.7ms preprocess, 367.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\predict7
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...

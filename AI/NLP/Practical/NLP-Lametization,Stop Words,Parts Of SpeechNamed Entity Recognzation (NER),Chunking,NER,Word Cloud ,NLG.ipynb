# %%
# Lametization
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

lemmatizer = WordNetLemmatizer()

# Example
print(lemmatizer.lemmatize("running", pos='v'))  # Output: run
print(lemmatizer.lemmatize("better", pos='a'))   # Output: good
# Out:
# run
# good

# %%
# Stop Words

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Download stopwords once
nltk.download('stopwords')
nltk.download('punkt')

text = "This is a sample sentence showing how to remove stop words."

# Tokenize the text
words = word_tokenize(text)

# Remove stopwords
filtered_words = [word for word in words if word.lower() not in stopwords.words('english')]

print(filtered_words)
# Out:
# ['sample', 'sentence', 'showing', 'remove', 'stop', 'words', '.']
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\csair\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\csair\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Parts of Speech

import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

text = "The quick brown fox jumps over the lazy dog"
tokens = nltk.word_tokenize(text)
pos_tags = nltk.pos_tag(tokens)

print(pos_tags)
# Out:
# [('The', 'DT'), ('quick', 'JJ'), ('brown', 'NN'), ('fox', 'NN'), ('jumps', 'VBZ'), ('over', 'IN'), ('the', 'DT'), ('lazy', 'JJ'), ('dog', 'NN')]
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\csair\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\csair\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
pip install spacy
# Out:
# ...
#    ---------------------------------------- 0.0/11.8 MB ? eta -:--:--
#    --------- ------------------------------ 2.9/11.8 MB 15.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.6/11.8 MB 16.1 MB/s eta 0:00:01
#    -------------------------------- ------- 9.7/11.8 MB 15.9 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.8 MB 15.0 MB/s eta 0:00:01
#    ---------------------------------------- 11.8/11.8 MB 12.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/632.6 kB ? eta -:--:--
#    --------------------------------------- 632.6/632.6 kB 11.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 10.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    --------- ------------------------------ 3.1/12.6 MB 15.3 MB/s eta 0:00:01
# ...

# %%
# Parts of Speech
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp("The quick brown fox jumps over the lazy dog")

for token in doc:
    print(f"{token.text} -> {token.pos_} ({token.tag_})")
# Out:
# The -> DET (DT)
# quick -> ADJ (JJ)
# brown -> ADJ (JJ)
# fox -> NOUN (NN)
# jumps -> VERB (VBZ)
# over -> ADP (IN)
# the -> DET (DT)
# lazy -> ADJ (JJ)
# dog -> NOUN (NN)

# %%
# python -m spacy download en_core_web_sm
# !python -m spacy download en_core_web_sm


# Named Entity Recognization (NER)
import spacy

# Load the English NLP model
nlp = spacy.load("en_core_web_sm")

# Input text
text = "Apple is looking at buying U.K. startup for $1 billion on January 1st."

# Process the text
doc = nlp(text)

# Extract named entities
for ent in doc.ents:
    print(f"{ent.text} -> {ent.label_}")
# Out:
# ...
#   Using cached https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# Apple -> ORG
# U.K. -> GPE
# $1 billion -> MONEY
# January 1st -> DATE

# %%
# NLG
# Chunking 
import nltk

# Define the grammar for noun phrases
grammar = "NP: {<DT>?<JJ>*<NN>}"

# Create a chunk parser
chunk_parser = nltk.RegexpParser(grammar)

# Tokenize and tag
sentence = "The quick brown fox jumps over the lazy dog"
tokens = nltk.word_tokenize(sentence)
tagged = nltk.pos_tag(tokens)

# Parse chunks
chunk_tree = chunk_parser.parse(tagged)

# Visualize chunks
chunk_tree.draw()  # Opens a window with a tree diagram

# Or print noun phrases
for subtree in chunk_tree.subtrees():
    if subtree.label() == 'NP':
        print("Noun Phrase:", " ".join(word for word, tag in subtree))

# %%
pip install wordcloud matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    -------- ------------------------------- 3.4/15.5 MB 16.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 6.8/15.5 MB 16.1 MB/s eta 0:00:01
#    --------------------------- ------------ 10.5/15.5 MB 16.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.9/15.5 MB 15.9 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 15.7 MB/s eta 0:00:01
#    ---------------------------------------- 15.5/15.5 MB 12.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.5
#     Uninstalling numpy-2.2.5:
#       Successfully uninstalled numpy-2.2.5
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# WordCloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Sample text
text = """
Natural Language Processing makes human language accessible to machines.
Text analysis, part-of-speech tagging, named entity recognition,
sentiment analysis, and machine translation are core applications of NLP.
"""

text1=("Python Python Python Matplotlib Matplotlib Seaborn Network Plot Violin Chart Pandas Datascience Wordcloud Spider Radar Parrallel Alpha Color Brewer Density Scatter Barplot Barplot Boxplot Violinplot Treemap Stacked Area Chart Chart Visualization Dataviz Donut Pie Time-Series Wordcloud Wordcloud Sankey Bubble")

# Create the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
wordcloud1 = WordCloud(width=800, height=400, background_color='white').generate(text1)
    
# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()


# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud1, interpolation='bilinear')
plt.axis("off")
plt.show()

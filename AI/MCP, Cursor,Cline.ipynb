# %% [markdown]
# # LLM  : Its has massive Tex dat from multiple sources
# # Agentic AI : With few prompts the task can be achieved.To achieve these backedn llm is used .
# # MCP : Its like wiring system btw LLM and agentic AI [various tools, memories  and other systems]
#
#
# # For MCP to work node to be installed in your computer
# # MCP basics  Tutorial : https://www.youtube.com/watch?v=6Ll5uB8VQto&ab_channel=NareshiTechnologies
# # MCP Documentation : https://modelcontextprotocol.io/introduction
# # MCP Githyb : https://github.com/modelcontextprotocol

# %% [markdown]
# # MCP : Its like wiring system btw LLM and various tools, memories  and other systems /servers
#
#
# M--Model (LLM models like chatgpt, gemini ai,claude etc)
# C-Context (Chat History,Files,Tools)
# Protocols -Rules to be followed

# %% [markdown]
# # Cursor AI : It is used for vibe coding (Non technical can develop/code easily)

# %% [markdown]
# # Cline is a Autonomous Coding Agent :
#   Install cline extension in VS Code
#   You will have a new cline logo available .Click on it

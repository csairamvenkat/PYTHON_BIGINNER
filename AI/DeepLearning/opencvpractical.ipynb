# %%
import cv2
import numpy as np
import pandas as pd

# %%
input=cv2.imread(r"D:\Education\Datascience\PYTHON_BIGINNER\AI\DeepLearning\Tensorflow\Ganesha.jpeg") #gets array of image
input

# %%
cv2.imshow("Ganesha",input)  # dispalys image in other window
cv2.waitKey() # waits for key press to destroy

# %%
print("Height : ", int(input.shape[0]), "Pixels")
print("Width  : ", int(input.shape[1]), "Pixels")

# %%
import os
os.cwd()

# %%
cv2.imwrite('path/to/image_converted.png', input)
print("Image saved as image_converted.png")

# %% [markdown]
# # Face Detection

# %%
import numpy as np
import cv2

# Load the Haar Cascade for face detection
face_classifier = cv2.CascadeClassifier(r"D:\Education\Datascience\PYTHON_BIGINNER\AI\DeepLearning\Tensorflow\haarcascade_frontalface_default.xml")

# Load the image
image = cv2.imread(r"D:\Education\Datascience\PYTHON_BIGINNER\AI\DeepLearning\Tensorflow\Modi.jpeg")

#image = cv2.imread(r'C:\Users\A3MAX SOFTWARE TECH\Desktop\WORK\2. DATASCIENCE PROJECT\10. Computer vision\Computer-Vision-Tutorial-master\Computer-Vision-Tutorial-master\image_examples\5.jpg')
# Check if the image is loaded correctly
if image is None:
    print("Error: Image not found or cannot be loaded!")
    exit()  # Exit if image is not loaded

# Convert the image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Detect faces in the image
faces = face_classifier.detectMultiScale(gray, 1.3, 5)

# Check if faces are detected
if len(faces) == 0:
    print("No faces found!")
else:
    # Draw rectangles around the faces
    for (x, y, w, h) in faces:  # (x, y) is the top-left corner, and (w, h) is the width and height of the face
        cv2.rectangle(image, (x, y), (x + w, y + h), (127, 0, 255), 2)

    # Display the output image
    cv2.imshow('Face Detection', image)
    cv2.waitKey(0)  # Wait for a key press to close the window

# Close all OpenCV windows
cv2.destroyAllWindows()
cv2.waitKey()

# %% [markdown]
# # Face and Eye Detection

# %%
import numpy as np
import cv2

# Load the Haar Cascade for face detection
face_classifier = cv2.CascadeClassifier(r"D:\Education\Datascience\PYTHON_BIGINNER\AI\DeepLearning\Tensorflow\haarcascade_frontalface_default.xml")
eye_classifier=cv2.CascadeClassifier(r"D:\Education\Datascience\PYTHON_BIGINNER\AI\DeepLearning\Tensorflow\haarcascade_eye.xml")

# Load the image
image = cv2.imread(r"D:\Education\Datascience\PYTHON_BIGINNER\AI\DeepLearning\Tensorflow\man-and-woman-on-bench-smiling.jpg")

#image = cv2.imread(r'C:\Users\A3MAX SOFTWARE TECH\Desktop\WORK\2. DATASCIENCE PROJECT\10. Computer vision\Computer-Vision-Tutorial-master\Computer-Vision-Tutorial-master\image_examples\5.jpg')
# Check if the image is loaded correctly
if image is None:
    print("Error: Image not found or cannot be loaded!")
    exit()  # Exit if image is not loaded

# Convert the image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Detect faces in the image
faces = face_classifier.detectMultiScale(gray, 1.3, 5)

# Check if faces are detected
if len(faces) == 0:
    print("No faces found!")
else:
    # Draw rectangles around the faces
    for (x, y, w, h) in faces:  # (x, y) is the top-left corner, and (w, h) is the width and height of the face
        cv2.rectangle(image, (x, y), (x + w, y + h), (127, 0, 255), 2)
        for (x, y, w, h) in faces:
    # Draw a rectangle around the face
            cv2.rectangle(image, (x, y), (x + w, y + h), (127, 0, 255), 2)

    # Region of interest (ROI) for face
    roi_gray = gray[y:y + h, x:x + w]
    roi_color = image[y:y + h, x:x + w]

    # Detect eyes within the face region
    eyes = eye_classifier.detectMultiScale(roi_gray)

    for (ex, ey, ew, eh) in eyes:
        # Draw rectangle around each detected eye
        cv2.rectangle(roi_color, (ex, ey), (ex + ew, ey + eh), (255, 255, 0), 2)

    # Display the output image
    cv2.imshow('Face Detection', image)
    cv2.waitKey(0)  # Wait for a key press to close the window

# Close all OpenCV windows
cv2.destroyAllWindows()

# %% [markdown]
# # Full Body

# %%
fullbody_cascade = cv2.CascadeClassifier('D:\Education\Datascience\PYTHON_BIGINNER\AI\DeepLearning\Tensorflow\haarcascade_fullbody.xml')
if fullbody_cascade.empty():
    print("Failed to load cascade. Check the path.")
cap = cv2.VideoCapture('D:\Education\Datascience\PYTHON_BIGINNER\AI\DeepLearning\Tensorflow\People Walking.mp4')  # or use 0 for webcam
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Convert frame to grayscale (Haar works on gray)
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect full bodies
    bodies = fullbody_cascade.detectMultiScale(
        gray,
        scaleFactor=1.1,
        minNeighbors=3,
        minSize=(50, 100)  # adjust size for better detection
    )

    # Draw bounding boxes
    for (x, y, w, h) in bodies:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)

    # Show the frame
    cv2.imshow('Full Body Detection', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 14
#      11 gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#      13 # Detect full bodies
# ---> 14 bodies = fullbody_cascade.detectMultiScale(
#      15     gray,
#      16     scaleFactor=1.1,
#      17     minNeighbors=3,
#      18     minSize=(50, 100)  # adjust size for better detection
#      19 )
#      21 # Draw bounding boxes
#      22 for (x, y, w, h) in bodies:
#
# KeyboardInterrupt:

# %% [markdown]
# # Detect Cars

# %%
car_cascade = cv2.CascadeClassifier('D:\Education\Datascience\PYTHON_BIGINNER\AI\DeepLearning\Tensorflow\cars.xml')  # Make sure the path is correct
cap = cv2.VideoCapture('D:\Education\Datascience\PYTHON_BIGINNER\AI\DeepLearning\Tensorflow\Cars, Motorway, Speed. Free Stock Video.mp4')  # Or use 0 for webcam
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect cars
    cars = car_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=3)

    # Draw bounding boxes
    for (x, y, w, h) in cars:
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)

    cv2.imshow('Car Detection', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
car_cascade

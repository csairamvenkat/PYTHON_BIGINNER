# %% [markdown]
# # Modules
# Module is like namespace in c#.
# It can be resused in multiple locations

# %% [markdown]
# Special Method
# __init__ : It is a constructor
# __name__ : It calls main functions

# %%
def add(a,b)
 return a+b

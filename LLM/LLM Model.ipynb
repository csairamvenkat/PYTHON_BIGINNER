# %% [markdown]
# # Go To Ollama.com
# # Download Ollama Setup
# # Install
# # cmd and type ollama-->returns available commands
# # ollama list-->shows installed llm's
# # ollama pull mistral-->install mistral
# # ollama run mistral

# %%
OpenAIKey : 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

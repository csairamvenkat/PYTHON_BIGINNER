# %%
pip install -qu 'langchain[google-genai]'
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Usage:
#   c:\Users\csair\AppData\Local\anaconda3\python.exe -m pip install [options] <requirement specifier> [package-index-options] ...
#   c:\Users\csair\AppData\Local\anaconda3\python.exe -m pip install [options] -r <requirements file> [package-index-options] ...
#   c:\Users\csair\AppData\Local\anaconda3\python.exe -m pip install [options] [-e] <vcs project url> ...
#   c:\Users\csair\AppData\Local\anaconda3\python.exe -m pip install [options] [-e] <local project path> ...
#   c:\Users\csair\AppData\Local\anaconda3\python.exe -m pip install [options] <archive url/path> ...
#
# no such option: -u

# %%
# Google API Key : AIzaSyAnZEfDI7xQGvJCchJXaN95lP0XXtxAqY0
import getpass
import os
key="AIzaSyAnZEfDI7xQGvJCchJXaN95lP0XXtxAqY0"
if not os.environ.get("GOOGLE_API_KEY"):
  os.environ["GOOGLE_API_KEY"] = getpass.getpass(key)

from langchain.chat_models import init_chat_model

model = init_chat_model("gemini-2.0-flash", model_provider="google_genai")

response = model.invoke("What is the capital of France?")
print(response.content)
# Out:
# The capital of France is **Paris**.

# %% [markdown]
# Nodes are functions where logics are written
# edges are transactions--connects nodes and directs flow
#
# #GROQ_API_KEY : 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
# #LANGSMITH_API_KEY : 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

# %% [markdown]
# Langchain can be used for any AI models
# Langgraph is for complex apps
# Langflow is UI based flow system
# Langsmith is used for tracing

# %% [markdown]
# Langraph :Develop  agents using langraph

# %% [markdown]
# https://python.langchain.com/docs/concepts/prompt_templates/

# %%
import getpass
import os
key="AIzaSyAnZEfDI7xQGvJCchJXaN95lP0XXtxAqY0"
os.environ["GOOGLE_API_KEY"] = getpass.getpass(key)

# %%
# String PromptTemplates
from langchain_core.prompts import PromptTemplate

prompt_template = PromptTemplate.from_template("Tell me a joke about {topic}")

prompt_template.invoke({"topic": "cats"})
# Out:
# StringPromptValue(text='Tell me a joke about cats')

# %%
# ChatPromptTemplates
from langchain_core.prompts import ChatPromptTemplate

prompt_template = ChatPromptTemplate([
    ("system", "You are a helpful assistant"),
    ("user", "Tell me a joke about {topic}")
])

prompt_template.invoke({"topic": "cats"})
# Out:
# ChatPromptValue(messages=[SystemMessage(content='You are a helpful assistant', additional_kwargs={}, response_metadata={}), HumanMessage(content='Tell me a joke about cats', additional_kwargs={}, response_metadata={})])

# %%
# MessagesPlaceholder
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.messages import HumanMessage

prompt_template = ChatPromptTemplate([
    ("system", "You are a helpful assistant"),
    MessagesPlaceholder("msgs")
])

prompt_template.invoke({"msgs": [HumanMessage(content="hi!")]})
# Out:
# ChatPromptValue(messages=[SystemMessage(content='You are a helpful assistant', additional_kwargs={}, response_metadata={}), HumanMessage(content='hi!', additional_kwargs={}, response_metadata={})])

# %%
prompt_template = ChatPromptTemplate([
    ("system", "You are a helpful assistant"),
    ("placeholder", "{msgs}") # <-- This is the changed part
])

# %%
# Gemini AI Prompt 

# String PromptTemplates
from langchain_core.prompts import PromptTemplate

prompt_template = '''Explain me about Independence struggle of {country}'''
prompt=PromptTemplate(input_variables=["year"], template=prompt_template)

prompt.format(country="India")
# Out:
# 'Explain me about Independence struggle of India'

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
key="AIzaSyAnZEfDI7xQGvJCchJXaN95lP0XXtxAqY0"
llm= ChatGoogleGenerativeAI(model="gemini-1.5-flash", temperature=0.1,max_tokens=100, google_api_key=key)
chain = LLMChain(llm=llm, prompt=prompt)

chain.run({"country": "America"})
# Out:
# C:\Users\csair\AppData\Local\Temp\ipykernel_13040\818000309.py:6: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   chain = LLMChain(llm=llm, prompt=prompt)
# C:\Users\csair\AppData\Local\Temp\ipykernel_13040\818000309.py:8: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   chain.run({"country": "America"})
# ...

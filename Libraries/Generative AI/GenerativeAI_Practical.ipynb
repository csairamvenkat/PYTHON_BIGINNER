# %%
import os
os.environ['Gemini_API_KEY']="AIzaSyAnZEfDI7xQGvJCchJXaN95lP0XXtxAqY0"  # Gemini Api key can be generated from Google  AI Studio--https://aistudio.google.com/app/apikey

# %%
# pip install -q -U google-generativeai  here U is update, q is quit after installation

# %%
import google.generativeai as genai
genai.configure(api_key='AIzaSyAnZEfDI7xQGvJCchJXaN95lP0XXtxAqY0')
model=genai.GenerativeModel("gemini-2.0-flash")
response=model.generate_content('Explain How AI Works')
print(response.text)
# Out:
# Okay, let's break down how Artificial Intelligence (AI) works. It's a vast field, so we'll cover the core concepts and key techniques without getting *too* bogged down in technical jargon.
#
# **The Basic Idea: Making Machines Think and Act Like Humans**
#
# At its simplest, AI aims to create machines that can perform tasks that typically require human intelligence.  This includes things like:
#
# *   **Learning:** Acquiring information and rules to improve performance over time.
# *   **Reasoning:** Using logic and inference to draw conclusions and make decisions.
# *   **Problem Solving:** Finding solutions to complex issues.
# *   **Perception:**  Understanding and interpreting sensory data (like images, sound, and text).
# *   **Natural Language Processing (NLP):** Understanding and generating human language.
#
# **Key Components and Techniques**
#
# Here's a breakdown of the main components and techniques that enable AI:
#
# ...

# %%
import google.generativeai as genai
genai.configure(api_key='AIzaSyAnZEfDI7xQGvJCchJXaN95lP0XXtxAqY0')
model=genai.GenerativeModel("gemini-2.0-flash")
response=model.generate_content('List down differences between D365 and Salesforce')
print(response.text)
# Out:
# Okay, here's a breakdown of the key differences between Dynamics 365 (D365) and Salesforce:
#
# **1.  Core Focus and Breadth:**
#
# *   **Salesforce:** Primarily started as a CRM (Customer Relationship Management) platform and has grown into a broader suite of cloud-based services. Its strength lies in its sales, service, and marketing automation capabilities.  It has a strong ecosystem of apps and partners built around the core CRM functionality.
# *   **Dynamics 365:**  A suite of interconnected business applications covering CRM, ERP (Enterprise Resource Planning), and other business functions. It's designed to provide a more holistic view of business operations, integrating sales, service, marketing, finance, supply chain, human resources, and more.  It's part of the larger Microsoft ecosystem and integrates tightly with other Microsoft products (Office 365, Power Platform, Azure, etc.).
#
# **2.  Pricing and Licensing:**
#
# ...

# %%
import google.generativeai as genai
genai.configure(api_key='AIzaSyAnZEfDI7xQGvJCchJXaN95lP0XXtxAqY0')
key='AIzaSyAnZEfDI7xQGvJCchJXaN95lP0XXtxAqY0'
model=genai.GenerativeModel("gemini-2.0-flash")
response=model.generate_content(f'What is the validity of this key {key}' )
print(response.text)
# Out:
# The key `AIzaSyAnZEfDI7xQGvJCchJXaN95lP0XXtxAqY0` *appears* to be a Google API key.  Here's why and what can be said about its validity:
#
# **Likely a Google API Key**
#
# *   **Format:** The `AIza` prefix is a strong indicator of a Google API key. All Google API keys start with this prefix. The remaining characters are alphanumeric.
# *   **Length:** The total length of the key is consistent with Google API keys.
#
# **Determining Validity - Impossible Without More Information & Access**
#
# It's **impossible for me (or anyone without access to the Google Cloud Console and Google's internal systems) to definitively say whether this key is valid or not.** Here's why:
#
# 1.  **Google's Backend:** The validity of the key is determined by Google's systems. They track usage, quotas, restrictions, and whether a key has been disabled or revoked. I have no access to these systems.
#
# ...

# %%
import google.generativeai as genai
genai.configure(api_key=os.environ['Gemini_API_KEY'])

# %%
model=genai.GenerativeModel('gemini-2.0-flash-exp')
response=model.generate_content('What is the life span of person' )
print(response.text)
# Out:
# The lifespan of a person is a complex topic with no single answer. It varies significantly depending on factors like:
#
# *   **Genetics:** Some people are predisposed to longer or shorter lives due to their inherited genes.
# *   **Lifestyle:** Diet, exercise, smoking, alcohol consumption, and stress levels all play a major role.
# *   **Healthcare:** Access to quality medical care and preventative treatments has a significant impact.
# *   **Environment:** Exposure to pollution, toxins, and other environmental hazards can affect lifespan.
# *   **Socioeconomic factors:** Income, education, and access to resources can influence health and lifespan.
# *   **Sex:** On average, women tend to live longer than men.
#
# **Here are some ways to think about average lifespan:**
#
# ...

# %%
pip install ipython
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pathlib 
import textwrap
import google.generativeai as genai
from IPython.display import display
from IPython.display import Markdown

def to_markdown(text):
    text=text.replace('*', ' *')
    return Markdown(textwrap.indent(text,'>',predicate=lambda _:True))
for m in genai.list_models():
    if 'generateContent' in m.supported_generation_methods:
        print(m.name)
# Out:
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# ...

# %%
import PIL.Image
img=PIL.Image.open(r'C:\Users\sai.venkat\OneDrive\DataScience\Python\PYTHON_BIGINNER\Libraries\Generative AI\ganesha.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x217>

# %%
model=genai.GenerativeModel('models/gemini-2.0-pro-exp-02-05')
response=model.generate_content(img)
to_markdown(response.text)
# Out:
# >Here are some details about the image, focusing on its religious and cultural context:
# >
# > * *Subject: * * The image depicts Ganesha (also spelled Ganesh, Ganapati), a highly revered deity in Hinduism.
# >
# > * *Key Iconography: * *
# >
# > *    * *Elephant Head: * * Ganesha's most distinctive feature, symbolizing wisdom, understanding, and a discerning intellect.
# > *    * *Large Ears: * * Represent the ability to listen attentively to devotees and gather knowledge.
# > *    * *Pot Belly: * * Symbolizes generosity, the ability to digest all good and bad in life, and the vastness of the universe.
# > *    * *Four Arms: * * Depict different attributes and powers. The specific items held in the hands can vary, but often include:
# >     *    * *Axe (Parashu): * * To cut away attachments and obstacles.
# >     *    * *Rope (Pasha): * * To pull devotees closer to the truth and restrain them from straying.
# ...

# %%
import pandas as pd 
import numpy as np

# %%
RandomContact=pd.read_csv(r'C:\Users\sai.venkat\OneDrive\DataScience\Python\PYTHON_BIGINNER\Libraries\Pandas\Random_Contacts.csv')
RandomContact

# %%
CleanedCOntactData=RandomContact['name|address|phonenumber|emailaddress'].str.split('|')
CleanedCOntactData

# %% [markdown]
# # Write File to CSV

# %%
import pandas as pd

# Sample data (CleanedCOntactData)
CleanedCOntactDataList = CleanedCOntactData.values.tolist()


# Define the header (column names)
header = ['name', 'address', 'phonenumber', 'emailaddress']
# Create DataFrame with specified column names

df = pd.DataFrame(CleanedCOntactDataList, columns=header)

# Write To Csv
df.to_csv('Delimitted Contacts.csv', index=False)

# %% [markdown]
# # Class Data

# %%
RandomAddresses=pd.read_excel(r'C:\Users\sai.venkat\OneDrive\DataScience\Python\PYTHON_BIGINNER\Libraries\Pandas\Bangalore_Addresses.xlsx')
RandomAddresses
# Out:
#                                          Address       Date              Time
# 0    93 6thBlock, Marathahalli, Bangalore-560100  30-Sep-17    5hr 25min 1sec
# 1    96 9thBlock, Marathahalli, Bangalore-560100  25-Nov-17   5hr 23min 35sec
# 2    96 9thBlock, Marathahalli, Bangalore-560100  10-Mar-17    7hr 1min 41sec
# 3    93 6thBlock, Marathahalli, Bangalore-560100  31-Oct-17   3hr 36min 16sec
# 4    94 7thBlock, Marathahalli, Bangalore-560100  06-Dec-17  18hr 46min 57sec
# ..                                           ...        ...               ...
# 995  93 6thBlock, Marathahalli, Bangalore-560100  31-Jan-17   3hr 11min 22sec
# 996  93 6thBlock, Marathahalli, Bangalore-560100  29-Nov-17    6hr 22min 0sec
# 997  93 6thBlock, Marathahalli, Bangalore-560100  13-Sep-17   9hr 39min 13sec
# 998  96 9thBlock, Marathahalli, Bangalore-560100  18-Jan-17   14hr 34min 8sec
# 999  94 7thBlock, Marathahalli, Bangalore-560100  24-Jun-17   9hr 44min 19sec
#
# [1000 rows x 3 columns]

# %%
Banglore_Address_Split=RandomAddresses['Address'].str.split(r'[,\s-]+',expand=True)
Banglore_Address_Split
# Out:
#       0         1             2          3       4
# 0    93  6thBlock  Marathahalli  Bangalore  560100
# 1    96  9thBlock  Marathahalli  Bangalore  560100
# 2    96  9thBlock  Marathahalli  Bangalore  560100
# 3    93  6thBlock  Marathahalli  Bangalore  560100
# 4    94  7thBlock  Marathahalli  Bangalore  560100
# ..   ..       ...           ...        ...     ...
# 995  93  6thBlock  Marathahalli  Bangalore  560100
# 996  93  6thBlock  Marathahalli  Bangalore  560100
# 997  93  6thBlock  Marathahalli  Bangalore  560100
# 998  96  9thBlock  Marathahalli  Bangalore  560100
# 999  94  7thBlock  Marathahalli  Bangalore  560100
#
# [1000 rows x 5 columns]

# %%
Banglore_Date_Split=RandomAddresses['Date'].str.split(r'[,\s-]+',expand=True)
Banglore_Date_Split
# Out:
#       0    1   2
# 0    30  Sep  17
# 1    25  Nov  17
# 2    10  Mar  17
# 3    31  Oct  17
# 4    06  Dec  17
# ..   ..  ...  ..
# 995  31  Jan  17
# 996  29  Nov  17
# 997  13  Sep  17
# 998  18  Jan  17
# 999  24  Jun  17
#
# [1000 rows x 3 columns]

# %%
Banglore_Time_Split=RandomAddresses['Time'].str.split(r'[,\s-]+',expand=True)
Banglore_Time_Split=Banglore_Time_Split.replace({'hr': ' Hours', 'min': ' Minutes', 'sec': ' Seconds'}, regex=True)
Banglore_Time_Split
# Out:
#             0           1           2
# 0     5 Hours  25 Minutes   1 Seconds
# 1     5 Hours  23 Minutes  35 Seconds
# 2     7 Hours   1 Minutes  41 Seconds
# 3     3 Hours  36 Minutes  16 Seconds
# 4    18 Hours  46 Minutes  57 Seconds
# ..        ...         ...         ...
# 995   3 Hours  11 Minutes  22 Seconds
# 996   6 Hours  22 Minutes   0 Seconds
# 997   9 Hours  39 Minutes  13 Seconds
# 998  14 Hours  34 Minutes   8 Seconds
# 999   9 Hours  44 Minutes  19 Seconds
#
# [1000 rows x 3 columns]

# %% [markdown]
# # To CSV

# %%
import pandas as pd


# Define the header (column names)
header = ['Building No.', 'Block Number ', 'Area', 'City','PinCode','Date','Month','Year','Hour','Minute','Sec']
UpdatedDf=pd.concat([Banglore_Address_Split,Banglore_Date_Split,Banglore_Time_Split],axis=1)
# Sample data (CleanedCOntactData)
UpdatedDfList = UpdatedDf.values.tolist()
# Create DataFrame with specified column names
df = pd.DataFrame(UpdatedDfList, columns=header)

# Write To Csv
df.to_csv('Delimitted Addresses.csv', index=False)
# Out:
#       0         1             2          3       4   0    1   2         0  \
# 0    93  6thBlock  Marathahalli  Bangalore  560100  30  Sep  17   5 Hours
# 1    96  9thBlock  Marathahalli  Bangalore  560100  25  Nov  17   5 Hours
# 2    96  9thBlock  Marathahalli  Bangalore  560100  10  Mar  17   7 Hours
# 3    93  6thBlock  Marathahalli  Bangalore  560100  31  Oct  17   3 Hours
# 4    94  7thBlock  Marathahalli  Bangalore  560100  06  Dec  17  18 Hours
# ..   ..       ...           ...        ...     ...  ..  ...  ..       ...
# 995  93  6thBlock  Marathahalli  Bangalore  560100  31  Jan  17   3 Hours
# 996  93  6thBlock  Marathahalli  Bangalore  560100  29  Nov  17   6 Hours
# 997  93  6thBlock  Marathahalli  Bangalore  560100  13  Sep  17   9 Hours
# 998  96  9thBlock  Marathahalli  Bangalore  560100  18  Jan  17  14 Hours
# 999  94  7thBlock  Marathahalli  Bangalore  560100  24  Jun  17   9 Hours
#
#               1           2
# 0    25 Minutes   1 Seconds
# 1    23 Minutes  35 Seconds
# 2     1 Minutes  41 Seconds
# 3    36 Minutes  16 Seconds
# 4    46 Minutes  57 Seconds
# ..          ...         ...
# 995  11 Minutes  22 Seconds
# 996  22 Minutes   0 Seconds
# 997  39 Minutes  13 Seconds
# 998  34 Minutes   8 Seconds
# 999  44 Minutes  19 Seconds
#
# [1000 rows x 11 columns]
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[27], line 14
#      11 df = pd.DataFrame(UpdatedDfList, columns=header)
#      13 # Write To Csv
# ---> 14 df.to_csv('Delimitted Addresses.csv', index=False)
#
# File c:\Users\sai.venkat\AppData\Local\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\sai.venkat\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File c:\Users\sai.venkat\AppData\Local\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\sai.venkat\AppData\Local\anaconda3\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File c:\Users\sai.venkat\AppData\Local\anaconda3\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'Delimitted Addresses.csv'

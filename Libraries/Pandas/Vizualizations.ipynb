# %% [markdown]
# # Outlier is a point far from other observations/data points
# # Outlier in Data Analysis is dangerous
# # Column==dimenion,attribute,feature
# # hue - parameter for color in lmplot
# # fit_reg is regression line in lm plot is for line in the graph.By default its True
# # Seaborn is used for statistical Representation

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize']=6,2
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'C:\Users\sai.venkat\OneDrive\DataScience\Python\PYTHON_BIGINNER\Libraries\Pandas\CountryGDP.csv')
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
df["InternetUsers"]
# Out:
# 0      78.9
# 1       5.9
# 2      19.1
# 3      57.2
# 4      88.0
#        ...
# 190    20.0
# 191    46.5
# 192     2.2
# 193    15.4
# 194    18.5
# Name: InternetUsers, Length: 195, dtype: float64

# %%
# Univariant analysis-->Plot graph with 1 col
vis1=sns.distplot(df["InternetUsers"])
plt.show()

# %%
vis2=sns.displot(df["InternetUsers"])
plt.show()

# %%
vis3=sns.distplot(df["InternetUsers"],bins=10)
plt.show()

# %% [markdown]
# # lower horizontal line==lower
# # higher horizontal line==high
# # Middle horizontal line==mean
# # btw Middle and low horizontal line==25 percentile
# # btw Middle and high  horizontal line==75 percentile
# # outlier which is not near to the other values.Its very dangerous

# %%
# Bi Variant Analysis
vis4=sns.boxplot(data=df,x='IncomeGroup',y='BirthRate',patch_artist=True)
plt.rcParams['figure.figsize']=10,5
plt.show()

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
vis4 = sns.lmplot(data = df,x = 'InternetUsers', y = 'BirthRate')
plt.show()

# %%
vis5=sns.lmplot(data=df,x='InternetUsers',y='BirthRate',fit_reg=False)   # fit_reg is for horizontal grpah line by default its true
plt.show()

# %%
vis6 = sns.lmplot(data = df,x = 'InternetUsers', y = 'BirthRate',
                  fit_reg = False,hue = 'IncomeGroup') #hue - parameter for color
plt.show()

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
vis7=sns.distplot(df["InternetUsers"],hist=True)
plt.show()
vis8=sns.distplot(df["InternetUsers"],hist=False)
plt.show()

# %% [markdown]
# Sree Rama
# Machine will learn from historical data
# Historical data is always raw
# Raw Data-Clean- Build Model-Test Model-Predict model on future data-Deploy
#
# # ML is of 2 types supervised and Unsupervised
# # ML User Trains Model and LLM user doesnot train model rather use it
#
# # ML has 3 phases-->
#   Training Phase-->Applied on historical data
#   Testing Phase -->Applied on historical data
#   Validation Phase-->Applied on Future data
#
# # Machine Learning Pipeline -->Complete Steps from
#       Gather Data
#       Prepare Data
#       Choosing Model
#       Training
#       Evaluation
#       Hyper parameter Training
#
#
# Split Ratio for training vs test
#       75:25
#       70:30
#       80:20
#       85:15
#
# # ML Frameworks used
# sklearn or (sckit learn)
# xgboost(Extreme Gradient Boosting)
# LGBM(Light Gradient Boosting Machine)

# %% [markdown]
# # Data Preprocessing
# Dependent variables never have missing data
#  We have data set
#  Divide data into x and y (independent variable and dependent variable)
#  x and y divided into train and test based on above split ratio as x train ,x test and y train and y test
#
#  We a re using impute transformer and simpleimputer-->It will fill missing vales with mean,median and mode strategy
# Irrelevant attributes can be deleted
#
#  # Fit and Transform can be done using various strategies like mean,median mode and transformers.

# %% [markdown]
# # Overfitting and Underfitting  this results in high error less accuracy
#
# 4 split ration-->x train y train xtest and ytest
# To train model : x train and ytrain
#   # Overfitting  :Train model with more data /attributes which are not necessary-->To overcome it remove irrelevant attributes--> This can be done using
#             PCA(Principal Component Analysis)
#             Crosss Validation
#             Regularization
#             Ensamble Learning
#             Drop out the neurons
#  # Underfitting  :Train model with less data /attributes which are  necessary-->To overcome it add more attributes
#  # Best Fit :Train model with relevant data and attributes

# %% [markdown]
# # 20-3-2025
# # Regression
#    # Linear Regression Algorithm/Models
#       # Simple Linear Regression
#       # Multiple Linear Regression
#             L1 Reg
#             L2 Reg
#             Gradient descent
#             Stocastic Gradient descent
#             Batch Gradient descent
#             Time Series
#    # Non Linear Regression Algorithm/Models
#             Polynomial Regression
#             Support Vector Regression
#             Decission Tree Regression
#             Random Forest Regression
#             Knearest neighbour Regression
#             aan Regression
#             lgbm Regression

# %% [markdown]
# # Simple Linear Regression
#
# y=mx+c
# slope (m)=Summation(x-xbar)(y-ybar)/summation of (square of (x-xbar) )
# y cap=mx+c   we get y bar by substituting m and c from above calculations ( where m is calculated on above formula,x is actual point and c is intercept calculated from y=mx+c)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as PROJECT/import seaborn as sns
import scipy.stats as stats

# %%
# Create Randopm Data Set
np.random.seed(100)

# %%
import numpy as np

np.random.seed(100)
print(np.random.rand(5))  # Generates the same random numbers every time you run it
# Out:
# [0.54340494 0.27836939 0.42451759 0.84477613 0.00471886]

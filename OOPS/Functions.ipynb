# %%
def helloWorld():
 print("Hello World")
 print("Hello World 2")
helloWorld()
# Out:
# Hello World
# Hello World 2

# %%
def add(x,y):
    c=x+y
    return c
# Out:
# 11
# saiRam

# %%
def returnedCatchingFunc():
    c=add(5,6) 
    print(c)   
returnedCatchingFunc()
# Out:
# 11
# None

# %%
def add_sub(x,y):
    c=x+y
    d=x-y
    return c,d

# %%
result=add_sub(4,5)
print(result)
print(type(result))
# Out:
# (9, -1)
# <class 'tuple'>

# %%
result1,result2=add_sub(4,5)
print(result1)
print(result2)
# Out:
# 9
# -1

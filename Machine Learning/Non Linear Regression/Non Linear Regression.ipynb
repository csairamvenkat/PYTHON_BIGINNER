# %% [markdown]
# Simple Regression : y=b0+b1x1
# Multi Linear Regression : b0+b1x1+b2x2+b3x3.....
# Polynomial Regression :  b0+b1x1+b2xsquare+b3xcube....    Not used in realtime but .Here we reduce the degree of independent variables

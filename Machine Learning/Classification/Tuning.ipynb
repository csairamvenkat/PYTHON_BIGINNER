# %% [markdown]
# # Parameter Tuning : Sys provide params
# # Hyper Parameter Tuning : USer over write sys  params

# %% [markdown]
# # Model Tuning :  It optimizes parameters with optimized values. To do so we use gridsearch cv or random search cv
#
# Gridsearch cv and Random search cv
#  Refer 22-4-2025 class video

# %% [markdown]
# # AOC and ROC

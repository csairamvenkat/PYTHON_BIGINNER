# %% [markdown]
# 02-06-2025 Class
# # Time Series  -->  Data is collection of time
# # Cross Sectional Data-->Data is not collected based on time
# # Pooled Dat-->Combination of above both Time series and Cross Sectional data.

# %% [markdown]
#  # AR Model-->Auto Regression Model : Its considers previous data
#  # MA Model -->Moving Average Model -->It depends on past error.
#  # ARMA --> Combination of AR and MA Models.
#  # ARIMA-->ARMA + Integration-->
#     Stationary -->Constant Mean, Constant Variance and No Sesonality
#     If data is not stationary-->Convert to stationary and apply time series model
#
#   # Auto Co Relation Function  -->Consider direct and indirect lags
#   # Partial Auto Co Relation Function  -->Consider direct lags
#
#     Direct Lag-->Direct previous value consideration
#     Indirect Lag->We even consider the lag of previous immediate lag.
#
#  # ARIMAX-->  If there are any extra factors that are not available  but affect prediction we build arimax model.
#  # SARIMA-->For given short period of seasonal data
#  # SARIMAX--> For given short period of seasonal data where additional factors to be considered.
#
#  When mean is 0 and Standard Deviation=1 we call it as white noise.

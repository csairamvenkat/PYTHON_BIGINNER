# %% [markdown]
# High Bias and Low Variance --Under Fit--plotted graph will be very close to test data but far from train data
# Low Bias and High Variance --Over Fit--plotted graph will be very far from test data  but close to train data
# Best Fit--Good balance ntw variance and bias
# Point where x and y meet is called intercept
#
# # Feature Engineering--EDA Technique
# # Feature Scaling--> Min Max Scaller | Standard Scaller
# # Feature Selection--PCA,Reccursive Elimination(pvalue>0.5),L1

# %% [markdown]
# # How to Reduce Overfitting
#
# PCA
# Cross Validation
# Regularization
# Enable Learning
# Drop Out Neuron
# Business Understanding

# %% [markdown]
# # Regularization : Regularize the highest coeff of independent variable to lowest coef is called regularization
#
# Lasso Regression or Lasso Regularization or L1
# Ridge Regression  or Ridge Regularization  or L2
# Elastic Regression  or Elastic Regularization
#
#
# # Ridge Regression  or L2
# Eg : y=5x1+.2X2+29x3+7==>29 has more impact among 3 slopes/coeff==>Overfitting happens  if coeff are reduced to y=.1x1+1.5x2+2.5 x3+7==>This can reduce the overfitting this called Ridge regreesion
#
# Ridge Regression=Loss+ penalty square [penality= square of (weight1 +weight12 ) etc (Weight 1  is explained in Neural Networks)]
#
# # Lasso Regression or L1  : Here coefficient are made 0 ==>Removes attributes==>Feature elimination Technique
#
# Losso Regression = Loss+penalty [weight1+weight12]
#
#
# # Elastic Regression  ==> Its combination of L1 and L2
#
#
# Over fitting : It Can occur  because of High Bias and Low Variance    and    more features

# %% [markdown]
# # ML Transformers :
#
#  Imputation  : We use mean,median,mode
#
# ,Label Encoder,Normalization,Standardization
#
# # Normalization : Values are Scalled Down . Also called Min max Scaler  and also ranges btw 0 and 1
#    It doesnot follow Gaussian Distribution
#
# Normalized Value=(X-Xmin)/(Xmax-Xmin)
#
# # Standardization  : Values are scalled down  between -3 to 3
#
#   Standardization Value =(X-Mu)/Sigma
#   It  follow Gaussian Distribution
#
#
# By default we apply standardization then normalization

# %% [markdown]
# # 01-04-2025 Class
# # Gradient Descent :  Its a optimization algo that find best fit for training data to reach global minima by reducing loss func and increase accuracy
#
# Out of multiple lines best fit is global minima
#
# Loss function (ML)=cost function=sum of mean squared Error
# residual (Actual-calculated)
#
# Learning Rate or Momentum (should be less than 0.01): The rate at which the step size reaches the global minima.
#
# Math Calculated for every data point.Since calculation for every point is costly job we use stochastic Gradient descent
#
#
# # stochastic Gradient Descent (SGD) : Its calculated by selecting random data points. It is used in deep learning
#
#     SGD creates cluster of points,calculate mean and then global minima is calculated.
#     Here mean is taken as actual
# # Batch Gradient Descent : It is used in deep learning
#
#     Batch is created ,mean is calculated and then global minima is calculated
#
# SGD and BGD is better than Gradient Descent
#
# other optimal alogos :
# Adam,adagrade,adadelta,adamax,rmsprop

# %% [markdown]
# # EDA  Transformers :
#  One Hot encoder,Label Encoder,Dummy Variable

# %% [markdown]
# # NLP Transformers
# # Gen AI Transformers
# # NLP Transformers

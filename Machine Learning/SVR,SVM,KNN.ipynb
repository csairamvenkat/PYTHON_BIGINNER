# %% [markdown]
# # SVR : Select Vector Regression--Used in regression model i.e dependent variables are continious
# # SVM: SUpport vector Machine: Used in Classiffication model  i.e dependent variables are binary
# # SVR and SVM are same but changes is in dependent variables
#
#     SVR line is called hyper plane (Best Fit line in simple linear )==>y=mx+c or y=wx+b
#     point near to hyper plane and line passing through it and Line parallel to hyper plane is called Decission boundry or support vector line
#     upside of hyper plane is +ve and below it is -ve
#     Distance btw 2 support lines is called marginal distance==>    -a < y=wx+b < +a
#     Distance btw 2 msupport vectors should be maximum because we can adjust the error easily Eg :  --> In national highway we can overtake easily but in gully road its difficult.the path taken to over take is called adjusted error

# %% [markdown]
# # KNN  K-Nearest Neighbours
# Distance between 2 points is calculated baed on Euclid Distance. and which ever is near it will be considered
#
# Distance Matrix
#  Eucledian Distance (Distance between 2 points)--Shortest Distance
#  Man Hatten Distance (Distance between 2 points)----Farthest  Distance
#  CoSIne Similarity(Distance between 2 words)
#
# Based on class the distance is calculated
#
# n_neighbour :5 neighbours
# Weights :uniform or distance..if uniform same value for all
# algorithm{'auto', 'ball_tree', 'kd_tree', 'brute'}, default='auto'
# When p = 1, this is equivalent to using manhattan_distance (l1), and euclidean_distance (l2) for p = 2.

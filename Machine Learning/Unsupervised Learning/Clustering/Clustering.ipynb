# %% [markdown]
# # Clustering  : Eg grp of ppls visit hotel and 10 rate 1 10 rate 2 50 rate 3. It is clutering of rating
#   ---There will be no dependent variable in clustering
#   ---Clusetring is used in NLP
#   ----It is Unsupervised learning
# # Its Unstructured Data
#
# Data can be Continous,Binary,Descrete (Stops at 1 point. eg : marks max =100)
# PCA-- Based on Highest Eigen value and Eigen Vectors..Studied in Logistical with PCA as Practical
# K-Means
# Hierarchial
# DbScan

# %% [markdown]
# # PCA

# %% [markdown]
# # K-Means : Resume Project Customer Segmentation Project
#    Choose K  points randomly.Then calculate Eucleadean distance btw the new  point wrt to previous selected points .Which ever is nearest then it falls to that group.Then calculate the mean btw the 2 new points which becomes new centroid for that group.-->Repeat this process.
# -->No Dependent Variable
#     # Use cases:     Customer segmentation,    Image compression, Document clustering, Market basket analysis
#     # Diff Algos are used in this
#    # Elbow Method :
#        Elbow Graph-->X axis (No of clusturs) and Y axis WCSS (within-cluster Sum of Sqaures)
#
#   K is by default 8 clusters

# %% [markdown]
# # Hierarchial  : Elbow Graph exists
#
#
#   -->Its is of 2 types  agglomeritive and divisive clustering
#
# -->We create cluster by step by step approach
# # Agglomeritive :
#      Nearest points are made clusters. After connecting 2 points if and other point is nearer to them them that is made a new cluster.This grouping is called Dendogram.
#      Here Clustuers are built Bottom to Top Approach
#      Centroid exists
#   Eg : CD--> group1, AB --> group2 , E is near group 1 then group1 and E is made as Group 3. Lines that are drwan are called Dendograms
#
#   Linkage : Link btw dendograms
#   single Linkage:nearest linkage
#   complete Linkage: Farthest linkage  or Voor Hees Algorithm
#   average Linkage: UPGMA
#   Weighted Linkage:WPGMA
#   Centroid Linkage : UPGMC
#   Median Linkage : WPGMC
#   Word  Linkage
#
#   By default 2 clusters
#
# # Divisive:
#    Divide the cluster from top to bottom
#
#    Eg : ABCDE is set-->Then AB , CDE are made clusters
#        ->A,B is made a cluster,CD,E is made a cluster
#        -> A,B,C,D,E are made individual clusters

# %% [markdown]
# # DB Scan : It is used to identify outlier
#
# Min 3 points required.These 3 points are called core points
# Other ponts are called boundary points
#
# Core Point can be boundary point  to other and vice versa
#
# Noise points are far from boundary or core ponts.Nosise point is outlier.
